# %% [markdown]
# <a href="https://colab.research.google.com/github/Gust4voSales/duplicates-identification/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LOAD

# %%
import numpy as np
import pandas as pd
import sys
sys.path.append("..")

filename = 'Music_Brainz_20K.csv'

def get_database(filename=filename):
  df = pd.read_csv(filename)
  # df = df.sample(n=8000, random_state=42) # small dataset

  return df

# %% [markdown]
# # CLEAN DATABASE

# %% [markdown]
# ## Clean functions

# %%
# clean strings
import re 

STRING_COLUMNS = ['title','artist','album']

# replace NaN with '' on STRING_COLUMNS
def clean_strings(df):
  df[STRING_COLUMNS] = df[STRING_COLUMNS].replace(np.nan, '')
  return df

# We don't remove non alphanumerics now, because we wouldn't be able to 
# undestand anything when we analyze the data. So we call this function 
# when we calculate the strings_distance
def remove_non_alphanum(string: str):
  return re.sub(r'\W+', '', string)

# %%
# clean years

def convert_year(year):
    if len(year) == 2:
        if int(year) < 50:
            return int('20' + year)
        else:
            return int('19' + year)
    elif len(year) == 4:
      return int(year)
    
    return 0

def clean_years(df):
  # parse years to the same format
  df['year'] = df['year'].replace(np.nan, '0')

  # remove all non-numerics from year column (example: '02 ==> 02)
  df['year'] = df['year'].str.replace(r'\D+', '', regex=True)

  df['year'] = df['year'].apply(lambda x: convert_year(x))

  return df

# %%
# remove unnecessary columns

UNUSED_COLUMNS = ['CTID', 'id',	'SourceID', 'length', 'language']
def remove_unused_columns(df):
  return df.drop(columns = UNUSED_COLUMNS)

# %% [markdown]
# ## Clean everything

# %%
# a single function that calls all the above clean functions
def clean_db(df):
  df = remove_unused_columns(df)
  df = clean_strings(df)
  df = clean_years(df)
  df['number'] = df['number'].replace(np.nan, '')
  return df

# %% [markdown]
# # DISTANCES FUNCTIONS

# %% [markdown]
# ## Individual Attributes distances functions

# %%
# STRING distance (title, album and artist...)
import Levenshtein as lev

def string_distance(string1: str, string2: str):
  x = remove_non_alphanum(string1).lower()
  y = remove_non_alphanum(string2).lower()
  
  dist = lev.distance(x, y) 

  max_len = max(len(x), len(y))
  if (max_len == 0):
    return 0
  normalized = (max_len-dist) / max_len 
  normalized_dist = 1-normalized
  return normalized_dist

# %%
# year distance
def year_distance(year1: int, year2: int):
    if (year1==year2): 
      return 0
    return 1

# %%
# number_track distance
def number_track_distance(number_t1, number_t2):
  if str(number_t1).isnumeric() and str(number_t2).isnumeric():
    number_t1 = int(number_t1)
    number_t2 = int(number_t2)

  if(number_t1 == number_t2):
    return 0
  return 1

# %% [markdown]
# ## Custom Distance function

# %%
# custom distance function

title_w = 1.2
album_w = 1
artist_w = 1
number_track_w = .8
year_w = .5

def distance(item, item2):
  w_sum =   0

  title_dist = 0
  album_dist = 0
  artist_dist = 0
  year_dist = 0
  number_track_dist = 0
  
  if (item['title'] and item2['title']):
    title_dist = string_distance(item['title'], item2['title'])
    w_sum += title_w

  if (item['album'] and item2['album']):
    album_dist = string_distance(item['album'], item2['album'])
    w_sum += album_w

  if (item['artist'] and item2['artist']):
    artist_dist = string_distance(item['artist'], item2['artist'])
    w_sum += artist_w

  if (item['year']>0 and item2['year']>0):
    year_dist = year_distance(item['year'], item2['year'])
    w_sum += year_w

  if (str(item['number']).isnumeric() and str(item2['number']).isnumeric()):
    if (int(item['number'])>0 and int(item2['number'])>0):
      number_track_dist = number_track_distance(item['number'], item2['number'])
      w_sum += number_track_w

  if (w_sum == 0): # don't divide by 0, it could happen
    return 1.0
  else:
    dist = ( (title_dist*title_w) + (album_dist*album_w) + (artist_dist*artist_w)
    + (number_track_dist*number_track_w) + (year_dist*year_w) ) / w_sum
  return dist

# %%
def calculate_precision(df, clusters):
  total_precision = 0

  for centroid_TID in list(clusters.keys()):
    doubles_find = 0
    cluster_items_len = len(clusters[centroid_TID])
    
    centroid = clusters[centroid_TID][0]
    centroids_doubles_amount= len(df[df['CID'] == centroid['CID']])

    centroids_items = clusters[centroid_TID]

    for item in clusters[centroid_TID]:
      if(item['CID']==centroid['CID']):
        doubles_find+=1

    cluster_precision = doubles_find/centroids_doubles_amount
    total_precision+= cluster_precision
  
  return (total_precision/len(clusters))*100

# %% [markdown]
# # Testando

# %%
# from modules.PhonexStaticBlocking import PhonexStaticBlocking

# print(f"--LENDO A BASE: {filename}--")
# df = get_database(filename)

# print(f"  Limpando a base...")
# df = clean_db(df)

# print(f"  Tamanho da base: {len(df)}")
# blocker = SoundexBlocking(df, 'title')
# blocks = blocker.get_blocks()

# blocker2 = PhonexStaticBlocking(df, 'title', 10)
# blocks2 = blocker2.get_blocks()

# print(len(blocks))
# print(len(blocks2))

# %%
import time 
from modules.CustomKmeans import CustomKmeans 
from modules.CustomKmeansPolars import CustomKmeansPolars 
from modules.PhonexStaticBlocking import PhonexStaticBlocking
from modules.SoundexBlocking import SoundexBlocking


def avaliate(filename, block_size):
  print(f"--LENDO A BASE: {filename}--")
  df = get_database(filename)
  
  print(f"  Limpando a base...")
  df = clean_db(df)

  print(f"  Tamanho da base: {len(df)}")
  print(f"--Blocando em blocks de {block_size} elementos--")
  # blocker = PhonexStaticBlocking(df, 'title', block_size)
  # blocks = blocker.get_blocks()
  blocker = SoundexBlocking('title')
  blocks = blocker.generate_blocks(df)

  print(f"  Quantidade de blocos: {len(blocks)}")

  clusters=[]

  print("--CLUSTERIZAÇÃO--")
  customKmeans = CustomKmeansPolars(distanceFn=distance, uID_column='TID', threshold=0.4)
  start_time=time.time()
  for i,block in enumerate(blocks):
    print(' Clusterizando bloco ', i)
    returned_clusters = customKmeans.run(block)
    clusters.append(returned_clusters)
  end_time=time.time()
  print(' >> Tempo de execução da clusterização na base: ',end_time - start_time,'s')

  print("--AVALIAÇÃO--")
  precisions = []
  for i in range(len(clusters)):  
    block_precision = calculate_precision(blocks[i], clusters[i]) 
    base_precision = calculate_precision(df, clusters[i])
    precisions.append([block_precision, base_precision])

  precisions_df = pd.DataFrame(precisions, columns=['Relacao Bloco', 'Relacao Base Toda'])
  for i, precision in enumerate(precisions):
    print(f"  BLOCO {i} (teve {len(clusters[i])} clusters): Precisão em relação ao bloco: {precision[0]} %. -- Precisão em relação a base: {precision[1]} %")
    print()

  print("Relacao Bloco: ",(precisions_df['Relacao Bloco'].sum())/len(blocks),' %')
  print("Relacao Base Toda: ",(precisions_df['Relacao Base Toda'].sum())/len(blocks),' %') 

  print()
  print('------------------------------------------------------------------')
  print()
  return precisions_df, clusters

# %%
precisions_df, clusters = avaliate(filename='Music_Brainz_20K.csv', block_size=20)
# avaliate(filename='Music_Brainz_200K.csv', block_size=1000)
print('Precisão:')
print(precisions_df)
precisions_df.to_csv('precisao.csv')
# Out:
# --LENDO A BASE: Music_Brainz_20K.csv--
#   Limpando a base...
#   Tamanho da base: 19375
# --Blocando em blocks de 20 elementos--
#   Quantidade de blocos: 3142
# --CLUSTERIZAÇÃO--
#  Clusterizando bloco  0
#  Clusterizando bloco  1
#  Clusterizando bloco  2
#  Clusterizando bloco  3
#  Clusterizando bloco  4
#  Clusterizando bloco  5
#  Clusterizando bloco  6
#  Clusterizando bloco  7
#  Clusterizando bloco  8
#  Clusterizando bloco  9
#  Clusterizando bloco  10
#  Clusterizando bloco  11
#  Clusterizando bloco  12
#  Clusterizando bloco  13
#  Clusterizando bloco  14
#  Clusterizando bloco  15
#  Clusterizando bloco  16
#  Clusterizando bloco  17
#  Clusterizando bloco  18
#  Clusterizando bloco  19
#  Clusterizando bloco  20
#  Clusterizando bloco  21
#  Clusterizando bloco  22
#  Clusterizando bloco  23
#  Clusterizando bloco  24
#  Clusterizando bloco  25
#  Clusterizando bloco  26
#  Clusterizando bloco  27
#  Clusterizando bloco  28
#  Clusterizando bloco  29
#  Clusterizando bloco  30
#  Clusterizando bloco  31
#  Clusterizando bloco  32
#  Clusterizando bloco  33
#  Clusterizando bloco  34
#  Clusterizando bloco  35
#  Clusterizando bloco  36
#  Clusterizando bloco  37
#  Clusterizando bloco  38
#  Clusterizando bloco  39
#  Clusterizando bloco  40
#  Clusterizando bloco  41
#  Clusterizando bloco  42
#  Clusterizando bloco  43
#  Clusterizando bloco  44
#  Clusterizando bloco  45
#  Clusterizando bloco  46
#  Clusterizando bloco  47
#  Clusterizando bloco  48
#  Clusterizando bloco  49
#  Clusterizando bloco  50
#  Clusterizando bloco  51
#  Clusterizando bloco  52
#  Clusterizando bloco  53
#  Clusterizando bloco  54
#  Clusterizando bloco  55
#  Clusterizando bloco  56
#  Clusterizando bloco  57
#  Clusterizando bloco  58
#  Clusterizando bloco  59
#  Clusterizando bloco  60
#  Clusterizando bloco  61
#  Clusterizando bloco  62
#  Clusterizando bloco  63
#  Clusterizando bloco  64
#  Clusterizando bloco  65
#  Clusterizando bloco  66
#  Clusterizando bloco  67
#  Clusterizando bloco  68
#  Clusterizando bloco  69
#  Clusterizando bloco  70
#  Clusterizando bloco  71
#  Clusterizando bloco  72
#  Clusterizando bloco  73
#  Clusterizando bloco  74
#  Clusterizando bloco  75
#  Clusterizando bloco  76
#  Clusterizando bloco  77
#  Clusterizando bloco  78
#  Clusterizando bloco  79
#  Clusterizando bloco  80
#  Clusterizando bloco  81
#  Clusterizando bloco  82
#  Clusterizando bloco  83
#  Clusterizando bloco  84
#  Clusterizando bloco  85
#  Clusterizando bloco  86
#  Clusterizando bloco  87
#  Clusterizando bloco  88
#  Clusterizando bloco  89
#  Clusterizando bloco  90
#  Clusterizando bloco  91
#  Clusterizando bloco  92
#  Clusterizando bloco  93
#  Clusterizando bloco  94
#  Clusterizando bloco  95
#  Clusterizando bloco  96
#  Clusterizando bloco  97
#  Clusterizando bloco  98
#  Clusterizando bloco  99
#  Clusterizando bloco  100
#  Clusterizando bloco  101
#  Clusterizando bloco  102
#  Clusterizando bloco  103
#  Clusterizando bloco  104
#  Clusterizando bloco  105
#  Clusterizando bloco  106
#  Clusterizando bloco  107
#  Clusterizando bloco  108
#  Clusterizando bloco  109
#  Clusterizando bloco  110
#  Clusterizando bloco  111
#  Clusterizando bloco  112
#  Clusterizando bloco  113
#  Clusterizando bloco  114
#  Clusterizando bloco  115
#  Clusterizando bloco  116
#  Clusterizando bloco  117
#  Clusterizando bloco  118
#  Clusterizando bloco  119
#  Clusterizando bloco  120
#  Clusterizando bloco  121
#  Clusterizando bloco  122
#  Clusterizando bloco  123
#  Clusterizando bloco  124
#  Clusterizando bloco  125
#  Clusterizando bloco  126
#  Clusterizando bloco  127
#  Clusterizando bloco  128
#  Clusterizando bloco  129
#  Clusterizando bloco  130
#  Clusterizando bloco  131
#  Clusterizando bloco  132
#  Clusterizando bloco  133
#  Clusterizando bloco  134
#  Clusterizando bloco  135
#  Clusterizando bloco  136
#  Clusterizando bloco  137
#  Clusterizando bloco  138
#  Clusterizando bloco  139
#  Clusterizando bloco  140
#  Clusterizando bloco  141
#  Clusterizando bloco  142
#  Clusterizando bloco  143
#  Clusterizando bloco  144
#  Clusterizando bloco  145
#  Clusterizando bloco  146
#  Clusterizando bloco  147
#  Clusterizando bloco  148
#  Clusterizando bloco  149
#  Clusterizando bloco  150
#  Clusterizando bloco  151
#  Clusterizando bloco  152
#  Clusterizando bloco  153
#  Clusterizando bloco  154
#  Clusterizando bloco  155
#  Clusterizando bloco  156
#  Clusterizando bloco  157
#  Clusterizando bloco  158
#  Clusterizando bloco  159
#  Clusterizando bloco  160
#  Clusterizando bloco  161
#  Clusterizando bloco  162
#  Clusterizando bloco  163
#  Clusterizando bloco  164
#  Clusterizando bloco  165
#  Clusterizando bloco  166
#  Clusterizando bloco  167
#  Clusterizando bloco  168
#  Clusterizando bloco  169
#  Clusterizando bloco  170
#  Clusterizando bloco  171
#  Clusterizando bloco  172
#  Clusterizando bloco  173
#  Clusterizando bloco  174
#  Clusterizando bloco  175
#  Clusterizando bloco  176
#  Clusterizando bloco  177
#  Clusterizando bloco  178
#  Clusterizando bloco  179
#  Clusterizando bloco  180
#  Clusterizando bloco  181
#  Clusterizando bloco  182
#  Clusterizando bloco  183
#  Clusterizando bloco  184
#  Clusterizando bloco  185
#  Clusterizando bloco  186
#  Clusterizando bloco  187
#  Clusterizando bloco  188
#  Clusterizando bloco  189
#  Clusterizando bloco  190
#  Clusterizando bloco  191
#  Clusterizando bloco  192
#  Clusterizando bloco  193
#  Clusterizando bloco  194
#  Clusterizando bloco  195
#  Clusterizando bloco  196
#  Clusterizando bloco  197
#  Clusterizando bloco  198
#  Clusterizando bloco  199
#  Clusterizando bloco  200
#  Clusterizando bloco  201
#  Clusterizando bloco  202
#  Clusterizando bloco  203
#  Clusterizando bloco  204
#  Clusterizando bloco  205
#  Clusterizando bloco  206
#  Clusterizando bloco  207
#  Clusterizando bloco  208
#  Clusterizando bloco  209
#  Clusterizando bloco  210
#  Clusterizando bloco  211
#  Clusterizando bloco  212
#  Clusterizando bloco  213
#  Clusterizando bloco  214
#  Clusterizando bloco  215
#  Clusterizando bloco  216
#  Clusterizando bloco  217
#  Clusterizando bloco  218
#  Clusterizando bloco  219
#  Clusterizando bloco  220
#  Clusterizando bloco  221
#  Clusterizando bloco  222
#  Clusterizando bloco  223
#  Clusterizando bloco  224
#  Clusterizando bloco  225
#  Clusterizando bloco  226
#  Clusterizando bloco  227
#  Clusterizando bloco  228
#  Clusterizando bloco  229
#  Clusterizando bloco  230
#  Clusterizando bloco  231
#  Clusterizando bloco  232
#  Clusterizando bloco  233
#  Clusterizando bloco  234
#  Clusterizando bloco  235
#  Clusterizando bloco  236
#  Clusterizando bloco  237
#  Clusterizando bloco  238
#  Clusterizando bloco  239
#  Clusterizando bloco  240
#  Clusterizando bloco  241
#  Clusterizando bloco  242
#  Clusterizando bloco  243
#  Clusterizando bloco  244
#  Clusterizando bloco  245
#  Clusterizando bloco  246
#  Clusterizando bloco  247
#  Clusterizando bloco  248
#  Clusterizando bloco  249
#  Clusterizando bloco  250
#  Clusterizando bloco  251
#  Clusterizando bloco  252
#  Clusterizando bloco  253
#  Clusterizando bloco  254
#  Clusterizando bloco  255
#  Clusterizando bloco  256
#  Clusterizando bloco  257
#  Clusterizando bloco  258
#  Clusterizando bloco  259
#  Clusterizando bloco  260
#  Clusterizando bloco  261
#  Clusterizando bloco  262
#  Clusterizando bloco  263
#  Clusterizando bloco  264
#  Clusterizando bloco  265
#  Clusterizando bloco  266
#  Clusterizando bloco  267
#  Clusterizando bloco  268
#  Clusterizando bloco  269
#  Clusterizando bloco  270
#  Clusterizando bloco  271
#  Clusterizando bloco  272
#  Clusterizando bloco  273
#  Clusterizando bloco  274
#  Clusterizando bloco  275
#  Clusterizando bloco  276
#  Clusterizando bloco  277
#  Clusterizando bloco  278
#  Clusterizando bloco  279
#  Clusterizando bloco  280
#  Clusterizando bloco  281
#  Clusterizando bloco  282
#  Clusterizando bloco  283
#  Clusterizando bloco  284
#  Clusterizando bloco  285
#  Clusterizando bloco  286
#  Clusterizando bloco  287
#  Clusterizando bloco  288
#  Clusterizando bloco  289
#  Clusterizando bloco  290
#  Clusterizando bloco  291
#  Clusterizando bloco  292
#  Clusterizando bloco  293
#  Clusterizando bloco  294
#  Clusterizando bloco  295
#  Clusterizando bloco  296
#  Clusterizando bloco  297
#  Clusterizando bloco  298
#  Clusterizando bloco  299
#  Clusterizando bloco  300
#  Clusterizando bloco  301
#  Clusterizando bloco  302
#  Clusterizando bloco  303
#  Clusterizando bloco  304
#  Clusterizando bloco  305
#  Clusterizando bloco  306
#  Clusterizando bloco  307
#  Clusterizando bloco  308
#  Clusterizando bloco  309
#  Clusterizando bloco  310
#  Clusterizando bloco  311
#  Clusterizando bloco  312
#  Clusterizando bloco  313
#  Clusterizando bloco  314
#  Clusterizando bloco  315
#  Clusterizando bloco  316
#  Clusterizando bloco  317
#  Clusterizando bloco  318
#  Clusterizando bloco  319
#  Clusterizando bloco  320
#  Clusterizando bloco  321
#  Clusterizando bloco  322
#  Clusterizando bloco  323
#  Clusterizando bloco  324
#  Clusterizando bloco  325
#  Clusterizando bloco  326
#  Clusterizando bloco  327
#  Clusterizando bloco  328
#  Clusterizando bloco  329
#  Clusterizando bloco  330
#  Clusterizando bloco  331
#  Clusterizando bloco  332
#  Clusterizando bloco  333
#  Clusterizando bloco  334
#  Clusterizando bloco  335
#  Clusterizando bloco  336
#  Clusterizando bloco  337
#  Clusterizando bloco  338
#  Clusterizando bloco  339
#  Clusterizando bloco  340
#  Clusterizando bloco  341
#  Clusterizando bloco  342
#  Clusterizando bloco  343
#  Clusterizando bloco  344
#  Clusterizando bloco  345
#  Clusterizando bloco  346
#  Clusterizando bloco  347
#  Clusterizando bloco  348
#  Clusterizando bloco  349
#  Clusterizando bloco  350
#  Clusterizando bloco  351
#  Clusterizando bloco  352
#  Clusterizando bloco  353
#  Clusterizando bloco  354
#  Clusterizando bloco  355
#  Clusterizando bloco  356
#  Clusterizando bloco  357
#  Clusterizando bloco  358
#  Clusterizando bloco  359
#  Clusterizando bloco  360
#  Clusterizando bloco  361
#  Clusterizando bloco  362
#  Clusterizando bloco  363
#  Clusterizando bloco  364
#  Clusterizando bloco  365
#  Clusterizando bloco  366
#  Clusterizando bloco  367
#  Clusterizando bloco  368
#  Clusterizando bloco  369
#  Clusterizando bloco  370
#  Clusterizando bloco  371
#  Clusterizando bloco  372
#  Clusterizando bloco  373
#  Clusterizando bloco  374
#  Clusterizando bloco  375
#  Clusterizando bloco  376
#  Clusterizando bloco  377
#  Clusterizando bloco  378
#  Clusterizando bloco  379
#  Clusterizando bloco  380
#  Clusterizando bloco  381
#  Clusterizando bloco  382
#  Clusterizando bloco  383
#  Clusterizando bloco  384
#  Clusterizando bloco  385
#  Clusterizando bloco  386
#  Clusterizando bloco  387
#  Clusterizando bloco  388
#  Clusterizando bloco  389
#  Clusterizando bloco  390
#  Clusterizando bloco  391
#  Clusterizando bloco  392
#  Clusterizando bloco  393
#  Clusterizando bloco  394
#  Clusterizando bloco  395
#  Clusterizando bloco  396
#  Clusterizando bloco  397
#  Clusterizando bloco  398
#  Clusterizando bloco  399
#  Clusterizando bloco  400
#  Clusterizando bloco  401
#  Clusterizando bloco  402
#  Clusterizando bloco  403
#  Clusterizando bloco  404
#  Clusterizando bloco  405
#  Clusterizando bloco  406
#  Clusterizando bloco  407
#  Clusterizando bloco  408
#  Clusterizando bloco  409
#  Clusterizando bloco  410
#  Clusterizando bloco  411
#  Clusterizando bloco  412
#  Clusterizando bloco  413
#  Clusterizando bloco  414
#  Clusterizando bloco  415
#  Clusterizando bloco  416
#  Clusterizando bloco  417
#  Clusterizando bloco  418
#  Clusterizando bloco  419
#  Clusterizando bloco  420
#  Clusterizando bloco  421
#  Clusterizando bloco  422
#  Clusterizando bloco  423
#  Clusterizando bloco  424
#  Clusterizando bloco  425
#  Clusterizando bloco  426
#  Clusterizando bloco  427
#  Clusterizando bloco  428
#  Clusterizando bloco  429
#  Clusterizando bloco  430
#  Clusterizando bloco  431
#  Clusterizando bloco  432
#  Clusterizando bloco  433
#  Clusterizando bloco  434
#  Clusterizando bloco  435
#  Clusterizando bloco  436
#  Clusterizando bloco  437
#  Clusterizando bloco  438
#  Clusterizando bloco  439
#  Clusterizando bloco  440
#  Clusterizando bloco  441
#  Clusterizando bloco  442
#  Clusterizando bloco  443
#  Clusterizando bloco  444
#  Clusterizando bloco  445
#  Clusterizando bloco  446
#  Clusterizando bloco  447
#  Clusterizando bloco  448
#  Clusterizando bloco  449
#  Clusterizando bloco  450
#  Clusterizando bloco  451
#  Clusterizando bloco  452
#  Clusterizando bloco  453
#  Clusterizando bloco  454
#  Clusterizando bloco  455
#  Clusterizando bloco  456
#  Clusterizando bloco  457
#  Clusterizando bloco  458
#  Clusterizando bloco  459
#  Clusterizando bloco  460
#  Clusterizando bloco  461
#  Clusterizando bloco  462
#  Clusterizando bloco  463
#  Clusterizando bloco  464
#  Clusterizando bloco  465
#  Clusterizando bloco  466
#  Clusterizando bloco  467
#  Clusterizando bloco  468
#  Clusterizando bloco  469
#  Clusterizando bloco  470
#  Clusterizando bloco  471
#  Clusterizando bloco  472
#  Clusterizando bloco  473
#  Clusterizando bloco  474
#  Clusterizando bloco  475
#  Clusterizando bloco  476
#  Clusterizando bloco  477
#  Clusterizando bloco  478
#  Clusterizando bloco  479
#  Clusterizando bloco  480
#  Clusterizando bloco  481
#  Clusterizando bloco  482
#  Clusterizando bloco  483
#  Clusterizando bloco  484
#  Clusterizando bloco  485
#  Clusterizando bloco  486
#  Clusterizando bloco  487
#  Clusterizando bloco  488
#  Clusterizando bloco  489
#  Clusterizando bloco  490
#  Clusterizando bloco  491
#  Clusterizando bloco  492
#  Clusterizando bloco  493
#  Clusterizando bloco  494
#  Clusterizando bloco  495
#  Clusterizando bloco  496
#  Clusterizando bloco  497
#  Clusterizando bloco  498
#  Clusterizando bloco  499
#  Clusterizando bloco  500
#  Clusterizando bloco  501
#  Clusterizando bloco  502
#  Clusterizando bloco  503
#  Clusterizando bloco  504
#  Clusterizando bloco  505
#  Clusterizando bloco  506
#  Clusterizando bloco  507
#  Clusterizando bloco  508
#  Clusterizando bloco  509
#  Clusterizando bloco  510
#  Clusterizando bloco  511
#  Clusterizando bloco  512
#  Clusterizando bloco  513
#  Clusterizando bloco  514
#  Clusterizando bloco  515
#  Clusterizando bloco  516
#  Clusterizando bloco  517
#  Clusterizando bloco  518
#  Clusterizando bloco  519
#  Clusterizando bloco  520
#  Clusterizando bloco  521
#  Clusterizando bloco  522
#  Clusterizando bloco  523
#  Clusterizando bloco  524
#  Clusterizando bloco  525
#  Clusterizando bloco  526
#  Clusterizando bloco  527
#  Clusterizando bloco  528
#  Clusterizando bloco  529
#  Clusterizando bloco  530
#  Clusterizando bloco  531
#  Clusterizando bloco  532
#  Clusterizando bloco  533
#  Clusterizando bloco  534
#  Clusterizando bloco  535
#  Clusterizando bloco  536
#  Clusterizando bloco  537
#  Clusterizando bloco  538
#  Clusterizando bloco  539
#  Clusterizando bloco  540
#  Clusterizando bloco  541
#  Clusterizando bloco  542
#  Clusterizando bloco  543
#  Clusterizando bloco  544
#  Clusterizando bloco  545
#  Clusterizando bloco  546
#  Clusterizando bloco  547
#  Clusterizando bloco  548
#  Clusterizando bloco  549
#  Clusterizando bloco  550
#  Clusterizando bloco  551
#  Clusterizando bloco  552
#  Clusterizando bloco  553
#  Clusterizando bloco  554
#  Clusterizando bloco  555
#  Clusterizando bloco  556
#  Clusterizando bloco  557
#  Clusterizando bloco  558
#  Clusterizando bloco  559
#  Clusterizando bloco  560
#  Clusterizando bloco  561
#  Clusterizando bloco  562
#  Clusterizando bloco  563
#  Clusterizando bloco  564
#  Clusterizando bloco  565
#  Clusterizando bloco  566
#  Clusterizando bloco  567
#  Clusterizando bloco  568
#  Clusterizando bloco  569
#  Clusterizando bloco  570
#  Clusterizando bloco  571
#  Clusterizando bloco  572
#  Clusterizando bloco  573
#  Clusterizando bloco  574
#  Clusterizando bloco  575
#  Clusterizando bloco  576
#  Clusterizando bloco  577
#  Clusterizando bloco  578
#  Clusterizando bloco  579
#  Clusterizando bloco  580
#  Clusterizando bloco  581
#  Clusterizando bloco  582
#  Clusterizando bloco  583
#  Clusterizando bloco  584
#  Clusterizando bloco  585
#  Clusterizando bloco  586
#  Clusterizando bloco  587
#  Clusterizando bloco  588
#  Clusterizando bloco  589
#  Clusterizando bloco  590
#  Clusterizando bloco  591
#  Clusterizando bloco  592
#  Clusterizando bloco  593
#  Clusterizando bloco  594
#  Clusterizando bloco  595
#  Clusterizando bloco  596
#  Clusterizando bloco  597
#  Clusterizando bloco  598
#  Clusterizando bloco  599
#  Clusterizando bloco  600
#  Clusterizando bloco  601
#  Clusterizando bloco  602
#  Clusterizando bloco  603
#  Clusterizando bloco  604
#  Clusterizando bloco  605
#  Clusterizando bloco  606
#  Clusterizando bloco  607
#  Clusterizando bloco  608
#  Clusterizando bloco  609
#  Clusterizando bloco  610
#  Clusterizando bloco  611
#  Clusterizando bloco  612
#  Clusterizando bloco  613
#  Clusterizando bloco  614
#  Clusterizando bloco  615
#  Clusterizando bloco  616
#  Clusterizando bloco  617
#  Clusterizando bloco  618
#  Clusterizando bloco  619
#  Clusterizando bloco  620
#  Clusterizando bloco  621
#  Clusterizando bloco  622
#  Clusterizando bloco  623
#  Clusterizando bloco  624
#  Clusterizando bloco  625
#  Clusterizando bloco  626
#  Clusterizando bloco  627
#  Clusterizando bloco  628
#  Clusterizando bloco  629
#  Clusterizando bloco  630
#  Clusterizando bloco  631
#  Clusterizando bloco  632
#  Clusterizando bloco  633
#  Clusterizando bloco  634
#  Clusterizando bloco  635
#  Clusterizando bloco  636
#  Clusterizando bloco  637
#  Clusterizando bloco  638
#  Clusterizando bloco  639
#  Clusterizando bloco  640
#  Clusterizando bloco  641
#  Clusterizando bloco  642
#  Clusterizando bloco  643
#  Clusterizando bloco  644
#  Clusterizando bloco  645
#  Clusterizando bloco  646
#  Clusterizando bloco  647
#  Clusterizando bloco  648
#  Clusterizando bloco  649
#  Clusterizando bloco  650
#  Clusterizando bloco  651
#  Clusterizando bloco  652
#  Clusterizando bloco  653
#  Clusterizando bloco  654
#  Clusterizando bloco  655
#  Clusterizando bloco  656
#  Clusterizando bloco  657
#  Clusterizando bloco  658
#  Clusterizando bloco  659
#  Clusterizando bloco  660
#  Clusterizando bloco  661
#  Clusterizando bloco  662
#  Clusterizando bloco  663
#  Clusterizando bloco  664
#  Clusterizando bloco  665
#  Clusterizando bloco  666
#  Clusterizando bloco  667
#  Clusterizando bloco  668
#  Clusterizando bloco  669
#  Clusterizando bloco  670
#  Clusterizando bloco  671
#  Clusterizando bloco  672
#  Clusterizando bloco  673
#  Clusterizando bloco  674
#  Clusterizando bloco  675
#  Clusterizando bloco  676
#  Clusterizando bloco  677
#  Clusterizando bloco  678
#  Clusterizando bloco  679
#  Clusterizando bloco  680
#  Clusterizando bloco  681
#  Clusterizando bloco  682
#  Clusterizando bloco  683
#  Clusterizando bloco  684
#  Clusterizando bloco  685
#  Clusterizando bloco  686
#  Clusterizando bloco  687
#  Clusterizando bloco  688
#  Clusterizando bloco  689
#  Clusterizando bloco  690
#  Clusterizando bloco  691
#  Clusterizando bloco  692
#  Clusterizando bloco  693
#  Clusterizando bloco  694
#  Clusterizando bloco  695
#  Clusterizando bloco  696
#  Clusterizando bloco  697
#  Clusterizando bloco  698
#  Clusterizando bloco  699
#  Clusterizando bloco  700
#  Clusterizando bloco  701
#  Clusterizando bloco  702
#  Clusterizando bloco  703
#  Clusterizando bloco  704
#  Clusterizando bloco  705
#  Clusterizando bloco  706
#  Clusterizando bloco  707
#  Clusterizando bloco  708
#  Clusterizando bloco  709
#  Clusterizando bloco  710
#  Clusterizando bloco  711
#  Clusterizando bloco  712
#  Clusterizando bloco  713
#  Clusterizando bloco  714
#  Clusterizando bloco  715
#  Clusterizando bloco  716
#  Clusterizando bloco  717
#  Clusterizando bloco  718
#  Clusterizando bloco  719
#  Clusterizando bloco  720
#  Clusterizando bloco  721
#  Clusterizando bloco  722
#  Clusterizando bloco  723
#  Clusterizando bloco  724
#  Clusterizando bloco  725
#  Clusterizando bloco  726
#  Clusterizando bloco  727
#  Clusterizando bloco  728
#  Clusterizando bloco  729
#  Clusterizando bloco  730
#  Clusterizando bloco  731
#  Clusterizando bloco  732
#  Clusterizando bloco  733
#  Clusterizando bloco  734
#  Clusterizando bloco  735
#  Clusterizando bloco  736
#  Clusterizando bloco  737
#  Clusterizando bloco  738
#  Clusterizando bloco  739
#  Clusterizando bloco  740
#  Clusterizando bloco  741
#  Clusterizando bloco  742
#  Clusterizando bloco  743
#  Clusterizando bloco  744
#  Clusterizando bloco  745
#  Clusterizando bloco  746
#  Clusterizando bloco  747
#  Clusterizando bloco  748
#  Clusterizando bloco  749
#  Clusterizando bloco  750
#  Clusterizando bloco  751
#  Clusterizando bloco  752
#  Clusterizando bloco  753
#  Clusterizando bloco  754
#  Clusterizando bloco  755
#  Clusterizando bloco  756
#  Clusterizando bloco  757
#  Clusterizando bloco  758
#  Clusterizando bloco  759
#  Clusterizando bloco  760
#  Clusterizando bloco  761
#  Clusterizando bloco  762
#  Clusterizando bloco  763
#  Clusterizando bloco  764
#  Clusterizando bloco  765
#  Clusterizando bloco  766
#  Clusterizando bloco  767
#  Clusterizando bloco  768
#  Clusterizando bloco  769
#  Clusterizando bloco  770
#  Clusterizando bloco  771
#  Clusterizando bloco  772
#  Clusterizando bloco  773
#  Clusterizando bloco  774
#  Clusterizando bloco  775
#  Clusterizando bloco  776
#  Clusterizando bloco  777
#  Clusterizando bloco  778
#  Clusterizando bloco  779
#  Clusterizando bloco  780
#  Clusterizando bloco  781
#  Clusterizando bloco  782
#  Clusterizando bloco  783
#  Clusterizando bloco  784
#  Clusterizando bloco  785
#  Clusterizando bloco  786
#  Clusterizando bloco  787
#  Clusterizando bloco  788
#  Clusterizando bloco  789
#  Clusterizando bloco  790
#  Clusterizando bloco  791
#  Clusterizando bloco  792
#  Clusterizando bloco  793
#  Clusterizando bloco  794
#  Clusterizando bloco  795
#  Clusterizando bloco  796
#  Clusterizando bloco  797
#  Clusterizando bloco  798
#  Clusterizando bloco  799
#  Clusterizando bloco  800
#  Clusterizando bloco  801
#  Clusterizando bloco  802
#  Clusterizando bloco  803
#  Clusterizando bloco  804
#  Clusterizando bloco  805
#  Clusterizando bloco  806
#  Clusterizando bloco  807
#  Clusterizando bloco  808
#  Clusterizando bloco  809
#  Clusterizando bloco  810
#  Clusterizando bloco  811
#  Clusterizando bloco  812
#  Clusterizando bloco  813
#  Clusterizando bloco  814
#  Clusterizando bloco  815
#  Clusterizando bloco  816
#  Clusterizando bloco  817
#  Clusterizando bloco  818
#  Clusterizando bloco  819
#  Clusterizando bloco  820
#  Clusterizando bloco  821
#  Clusterizando bloco  822
#  Clusterizando bloco  823
#  Clusterizando bloco  824
#  Clusterizando bloco  825
#  Clusterizando bloco  826
#  Clusterizando bloco  827
#  Clusterizando bloco  828
#  Clusterizando bloco  829
#  Clusterizando bloco  830
#  Clusterizando bloco  831
#  Clusterizando bloco  832
#  Clusterizando bloco  833
#  Clusterizando bloco  834
#  Clusterizando bloco  835
#  Clusterizando bloco  836
#  Clusterizando bloco  837
#  Clusterizando bloco  838
#  Clusterizando bloco  839
#  Clusterizando bloco  840
#  Clusterizando bloco  841
#  Clusterizando bloco  842
#  Clusterizando bloco  843
#  Clusterizando bloco  844
#  Clusterizando bloco  845
#  Clusterizando bloco  846
#  Clusterizando bloco  847
#  Clusterizando bloco  848
#  Clusterizando bloco  849
#  Clusterizando bloco  850
#  Clusterizando bloco  851
#  Clusterizando bloco  852
#  Clusterizando bloco  853
#  Clusterizando bloco  854
#  Clusterizando bloco  855
#  Clusterizando bloco  856
#  Clusterizando bloco  857
#  Clusterizando bloco  858
#  Clusterizando bloco  859
#  Clusterizando bloco  860
#  Clusterizando bloco  861
#  Clusterizando bloco  862
#  Clusterizando bloco  863
#  Clusterizando bloco  864
#  Clusterizando bloco  865
#  Clusterizando bloco  866
#  Clusterizando bloco  867
#  Clusterizando bloco  868
#  Clusterizando bloco  869
#  Clusterizando bloco  870
#  Clusterizando bloco  871
#  Clusterizando bloco  872
#  Clusterizando bloco  873
#  Clusterizando bloco  874
#  Clusterizando bloco  875
#  Clusterizando bloco  876
#  Clusterizando bloco  877
#  Clusterizando bloco  878
#  Clusterizando bloco  879
#  Clusterizando bloco  880
#  Clusterizando bloco  881
#  Clusterizando bloco  882
#  Clusterizando bloco  883
#  Clusterizando bloco  884
#  Clusterizando bloco  885
#  Clusterizando bloco  886
#  Clusterizando bloco  887
#  Clusterizando bloco  888
#  Clusterizando bloco  889
#  Clusterizando bloco  890
#  Clusterizando bloco  891
#  Clusterizando bloco  892
#  Clusterizando bloco  893
#  Clusterizando bloco  894
#  Clusterizando bloco  895
#  Clusterizando bloco  896
#  Clusterizando bloco  897
#  Clusterizando bloco  898
#  Clusterizando bloco  899
#  Clusterizando bloco  900
#  Clusterizando bloco  901
#  Clusterizando bloco  902
#  Clusterizando bloco  903
#  Clusterizando bloco  904
#  Clusterizando bloco  905
#  Clusterizando bloco  906
#  Clusterizando bloco  907
#  Clusterizando bloco  908
#  Clusterizando bloco  909
#  Clusterizando bloco  910
#  Clusterizando bloco  911
#  Clusterizando bloco  912
#  Clusterizando bloco  913
#  Clusterizando bloco  914
#  Clusterizando bloco  915
#  Clusterizando bloco  916
#  Clusterizando bloco  917
#  Clusterizando bloco  918
#  Clusterizando bloco  919
#  Clusterizando bloco  920
#  Clusterizando bloco  921
#  Clusterizando bloco  922
#  Clusterizando bloco  923
#  Clusterizando bloco  924
#  Clusterizando bloco  925
#  Clusterizando bloco  926
#  Clusterizando bloco  927
#  Clusterizando bloco  928
#  Clusterizando bloco  929
#  Clusterizando bloco  930
#  Clusterizando bloco  931
#  Clusterizando bloco  932
#  Clusterizando bloco  933
#  Clusterizando bloco  934
#  Clusterizando bloco  935
#  Clusterizando bloco  936
#  Clusterizando bloco  937
#  Clusterizando bloco  938
#  Clusterizando bloco  939
#  Clusterizando bloco  940
#  Clusterizando bloco  941
#  Clusterizando bloco  942
#  Clusterizando bloco  943
#  Clusterizando bloco  944
#  Clusterizando bloco  945
#  Clusterizando bloco  946
#  Clusterizando bloco  947
#  Clusterizando bloco  948
#  Clusterizando bloco  949
#  Clusterizando bloco  950
#  Clusterizando bloco  951
#  Clusterizando bloco  952
#  Clusterizando bloco  953
#  Clusterizando bloco  954
#  Clusterizando bloco  955
#  Clusterizando bloco  956
#  Clusterizando bloco  957
#  Clusterizando bloco  958
#  Clusterizando bloco  959
#  Clusterizando bloco  960
#  Clusterizando bloco  961
#  Clusterizando bloco  962
#  Clusterizando bloco  963
#  Clusterizando bloco  964
#  Clusterizando bloco  965
#  Clusterizando bloco  966
#  Clusterizando bloco  967
#  Clusterizando bloco  968
#  Clusterizando bloco  969
#  Clusterizando bloco  970
#  Clusterizando bloco  971
#  Clusterizando bloco  972
#  Clusterizando bloco  973
#  Clusterizando bloco  974
#  Clusterizando bloco  975
#  Clusterizando bloco  976
#  Clusterizando bloco  977
#  Clusterizando bloco  978
#  Clusterizando bloco  979
#  Clusterizando bloco  980
#  Clusterizando bloco  981
#  Clusterizando bloco  982
#  Clusterizando bloco  983
#  Clusterizando bloco  984
#  Clusterizando bloco  985
#  Clusterizando bloco  986
#  Clusterizando bloco  987
#  Clusterizando bloco  988
#  Clusterizando bloco  989
#  Clusterizando bloco  990
#  Clusterizando bloco  991
#  Clusterizando bloco  992
#  Clusterizando bloco  993
#  Clusterizando bloco  994
#  Clusterizando bloco  995
#  Clusterizando bloco  996
#  Clusterizando bloco  997
#  Clusterizando bloco  998
#  Clusterizando bloco  999
#  Clusterizando bloco  1000
#  Clusterizando bloco  1001
#  Clusterizando bloco  1002
#  Clusterizando bloco  1003
#  Clusterizando bloco  1004
#  Clusterizando bloco  1005
#  Clusterizando bloco  1006
#  Clusterizando bloco  1007
#  Clusterizando bloco  1008
#  Clusterizando bloco  1009
#  Clusterizando bloco  1010
#  Clusterizando bloco  1011
#  Clusterizando bloco  1012
#  Clusterizando bloco  1013
#  Clusterizando bloco  1014
#  Clusterizando bloco  1015
#  Clusterizando bloco  1016
#  Clusterizando bloco  1017
#  Clusterizando bloco  1018
#  Clusterizando bloco  1019
#  Clusterizando bloco  1020
#  Clusterizando bloco  1021
#  Clusterizando bloco  1022
#  Clusterizando bloco  1023
#  Clusterizando bloco  1024
#  Clusterizando bloco  1025
#  Clusterizando bloco  1026
#  Clusterizando bloco  1027
#  Clusterizando bloco  1028
#  Clusterizando bloco  1029
#  Clusterizando bloco  1030
#  Clusterizando bloco  1031
#  Clusterizando bloco  1032
#  Clusterizando bloco  1033
#  Clusterizando bloco  1034
#  Clusterizando bloco  1035
#  Clusterizando bloco  1036
#  Clusterizando bloco  1037
#  Clusterizando bloco  1038
#  Clusterizando bloco  1039
#  Clusterizando bloco  1040
#  Clusterizando bloco  1041
#  Clusterizando bloco  1042
#  Clusterizando bloco  1043
#  Clusterizando bloco  1044
#  Clusterizando bloco  1045
#  Clusterizando bloco  1046
#  Clusterizando bloco  1047
#  Clusterizando bloco  1048
#  Clusterizando bloco  1049
#  Clusterizando bloco  1050
#  Clusterizando bloco  1051
#  Clusterizando bloco  1052
#  Clusterizando bloco  1053
#  Clusterizando bloco  1054
#  Clusterizando bloco  1055
#  Clusterizando bloco  1056
#  Clusterizando bloco  1057
#  Clusterizando bloco  1058
#  Clusterizando bloco  1059
#  Clusterizando bloco  1060
#  Clusterizando bloco  1061
#  Clusterizando bloco  1062
#  Clusterizando bloco  1063
#  Clusterizando bloco  1064
#  Clusterizando bloco  1065
#  Clusterizando bloco  1066
#  Clusterizando bloco  1067
#  Clusterizando bloco  1068
#  Clusterizando bloco  1069
#  Clusterizando bloco  1070
#  Clusterizando bloco  1071
#  Clusterizando bloco  1072
#  Clusterizando bloco  1073
#  Clusterizando bloco  1074
#  Clusterizando bloco  1075
#  Clusterizando bloco  1076
#  Clusterizando bloco  1077
#  Clusterizando bloco  1078
#  Clusterizando bloco  1079
#  Clusterizando bloco  1080
#  Clusterizando bloco  1081
#  Clusterizando bloco  1082
#  Clusterizando bloco  1083
#  Clusterizando bloco  1084
#  Clusterizando bloco  1085
#  Clusterizando bloco  1086
#  Clusterizando bloco  1087
#  Clusterizando bloco  1088
#  Clusterizando bloco  1089
#  Clusterizando bloco  1090
#  Clusterizando bloco  1091
#  Clusterizando bloco  1092
#  Clusterizando bloco  1093
#  Clusterizando bloco  1094
#  Clusterizando bloco  1095
#  Clusterizando bloco  1096
#  Clusterizando bloco  1097
#  Clusterizando bloco  1098
#  Clusterizando bloco  1099
#  Clusterizando bloco  1100
#  Clusterizando bloco  1101
#  Clusterizando bloco  1102
#  Clusterizando bloco  1103
#  Clusterizando bloco  1104
#  Clusterizando bloco  1105
#  Clusterizando bloco  1106
#  Clusterizando bloco  1107
#  Clusterizando bloco  1108
#  Clusterizando bloco  1109
#  Clusterizando bloco  1110
#  Clusterizando bloco  1111
#  Clusterizando bloco  1112
#  Clusterizando bloco  1113
#  Clusterizando bloco  1114
#  Clusterizando bloco  1115
#  Clusterizando bloco  1116
#  Clusterizando bloco  1117
#  Clusterizando bloco  1118
#  Clusterizando bloco  1119
#  Clusterizando bloco  1120
#  Clusterizando bloco  1121
#  Clusterizando bloco  1122
#  Clusterizando bloco  1123
#  Clusterizando bloco  1124
#  Clusterizando bloco  1125
#  Clusterizando bloco  1126
#  Clusterizando bloco  1127
#  Clusterizando bloco  1128
#  Clusterizando bloco  1129
#  Clusterizando bloco  1130
#  Clusterizando bloco  1131
#  Clusterizando bloco  1132
#  Clusterizando bloco  1133
#  Clusterizando bloco  1134
#  Clusterizando bloco  1135
#  Clusterizando bloco  1136
#  Clusterizando bloco  1137
#  Clusterizando bloco  1138
#  Clusterizando bloco  1139
#  Clusterizando bloco  1140
#  Clusterizando bloco  1141
#  Clusterizando bloco  1142
#  Clusterizando bloco  1143
#  Clusterizando bloco  1144
#  Clusterizando bloco  1145
#  Clusterizando bloco  1146
#  Clusterizando bloco  1147
#  Clusterizando bloco  1148
#  Clusterizando bloco  1149
#  Clusterizando bloco  1150
#  Clusterizando bloco  1151
#  Clusterizando bloco  1152
#  Clusterizando bloco  1153
#  Clusterizando bloco  1154
#  Clusterizando bloco  1155
#  Clusterizando bloco  1156
#  Clusterizando bloco  1157
#  Clusterizando bloco  1158
#  Clusterizando bloco  1159
#  Clusterizando bloco  1160
#  Clusterizando bloco  1161
#  Clusterizando bloco  1162
#  Clusterizando bloco  1163
#  Clusterizando bloco  1164
#  Clusterizando bloco  1165
#  Clusterizando bloco  1166
#  Clusterizando bloco  1167
#  Clusterizando bloco  1168
#  Clusterizando bloco  1169
#  Clusterizando bloco  1170
#  Clusterizando bloco  1171
#  Clusterizando bloco  1172
#  Clusterizando bloco  1173
#  Clusterizando bloco  1174
#  Clusterizando bloco  1175
#  Clusterizando bloco  1176
#  Clusterizando bloco  1177
#  Clusterizando bloco  1178
#  Clusterizando bloco  1179
#  Clusterizando bloco  1180
#  Clusterizando bloco  1181
#  Clusterizando bloco  1182
#  Clusterizando bloco  1183
#  Clusterizando bloco  1184
#  Clusterizando bloco  1185
#  Clusterizando bloco  1186
#  Clusterizando bloco  1187
#  Clusterizando bloco  1188
#  Clusterizando bloco  1189
#  Clusterizando bloco  1190
#  Clusterizando bloco  1191
#  Clusterizando bloco  1192
#  Clusterizando bloco  1193
#  Clusterizando bloco  1194
#  Clusterizando bloco  1195
#  Clusterizando bloco  1196
#  Clusterizando bloco  1197
#  Clusterizando bloco  1198
#  Clusterizando bloco  1199
#  Clusterizando bloco  1200
#  Clusterizando bloco  1201
#  Clusterizando bloco  1202
#  Clusterizando bloco  1203
#  Clusterizando bloco  1204
#  Clusterizando bloco  1205
#  Clusterizando bloco  1206
#  Clusterizando bloco  1207
#  Clusterizando bloco  1208
#  Clusterizando bloco  1209
#  Clusterizando bloco  1210
#  Clusterizando bloco  1211
#  Clusterizando bloco  1212
#  Clusterizando bloco  1213
#  Clusterizando bloco  1214
#  Clusterizando bloco  1215
#  Clusterizando bloco  1216
#  Clusterizando bloco  1217
#  Clusterizando bloco  1218
#  Clusterizando bloco  1219
#  Clusterizando bloco  1220
#  Clusterizando bloco  1221
#  Clusterizando bloco  1222
#  Clusterizando bloco  1223
#  Clusterizando bloco  1224
#  Clusterizando bloco  1225
#  Clusterizando bloco  1226
#  Clusterizando bloco  1227
#  Clusterizando bloco  1228
#  Clusterizando bloco  1229
#  Clusterizando bloco  1230
#  Clusterizando bloco  1231
#  Clusterizando bloco  1232
#  Clusterizando bloco  1233
#  Clusterizando bloco  1234
#  Clusterizando bloco  1235
#  Clusterizando bloco  1236
#  Clusterizando bloco  1237
#  Clusterizando bloco  1238
#  Clusterizando bloco  1239
#  Clusterizando bloco  1240
#  Clusterizando bloco  1241
#  Clusterizando bloco  1242
#  Clusterizando bloco  1243
#  Clusterizando bloco  1244
#  Clusterizando bloco  1245
#  Clusterizando bloco  1246
#  Clusterizando bloco  1247
#  Clusterizando bloco  1248
#  Clusterizando bloco  1249
#  Clusterizando bloco  1250
#  Clusterizando bloco  1251
#  Clusterizando bloco  1252
#  Clusterizando bloco  1253
#  Clusterizando bloco  1254
#  Clusterizando bloco  1255
#  Clusterizando bloco  1256
#  Clusterizando bloco  1257
#  Clusterizando bloco  1258
#  Clusterizando bloco  1259
#  Clusterizando bloco  1260
#  Clusterizando bloco  1261
#  Clusterizando bloco  1262
#  Clusterizando bloco  1263
#  Clusterizando bloco  1264
#  Clusterizando bloco  1265
#  Clusterizando bloco  1266
#  Clusterizando bloco  1267
#  Clusterizando bloco  1268
#  Clusterizando bloco  1269
#  Clusterizando bloco  1270
#  Clusterizando bloco  1271
#  Clusterizando bloco  1272
#  Clusterizando bloco  1273
#  Clusterizando bloco  1274
#  Clusterizando bloco  1275
#  Clusterizando bloco  1276
#  Clusterizando bloco  1277
#  Clusterizando bloco  1278
#  Clusterizando bloco  1279
#  Clusterizando bloco  1280
#  Clusterizando bloco  1281
#  Clusterizando bloco  1282
#  Clusterizando bloco  1283
#  Clusterizando bloco  1284
#  Clusterizando bloco  1285
#  Clusterizando bloco  1286
#  Clusterizando bloco  1287
#  Clusterizando bloco  1288
#  Clusterizando bloco  1289
#  Clusterizando bloco  1290
#  Clusterizando bloco  1291
#  Clusterizando bloco  1292
#  Clusterizando bloco  1293
#  Clusterizando bloco  1294
#  Clusterizando bloco  1295
#  Clusterizando bloco  1296
#  Clusterizando bloco  1297
#  Clusterizando bloco  1298
#  Clusterizando bloco  1299
#  Clusterizando bloco  1300
#  Clusterizando bloco  1301
#  Clusterizando bloco  1302
#  Clusterizando bloco  1303
#  Clusterizando bloco  1304
#  Clusterizando bloco  1305
#  Clusterizando bloco  1306
#  Clusterizando bloco  1307
#  Clusterizando bloco  1308
#  Clusterizando bloco  1309
#  Clusterizando bloco  1310
#  Clusterizando bloco  1311
#  Clusterizando bloco  1312
#  Clusterizando bloco  1313
#  Clusterizando bloco  1314
#  Clusterizando bloco  1315
#  Clusterizando bloco  1316
#  Clusterizando bloco  1317
#  Clusterizando bloco  1318
#  Clusterizando bloco  1319
#  Clusterizando bloco  1320
#  Clusterizando bloco  1321
#  Clusterizando bloco  1322
#  Clusterizando bloco  1323
#  Clusterizando bloco  1324
#  Clusterizando bloco  1325
#  Clusterizando bloco  1326
#  Clusterizando bloco  1327
#  Clusterizando bloco  1328
#  Clusterizando bloco  1329
#  Clusterizando bloco  1330
#  Clusterizando bloco  1331
#  Clusterizando bloco  1332
#  Clusterizando bloco  1333
#  Clusterizando bloco  1334
#  Clusterizando bloco  1335
#  Clusterizando bloco  1336
#  Clusterizando bloco  1337
#  Clusterizando bloco  1338
#  Clusterizando bloco  1339
#  Clusterizando bloco  1340
#  Clusterizando bloco  1341
#  Clusterizando bloco  1342
#  Clusterizando bloco  1343
#  Clusterizando bloco  1344
#  Clusterizando bloco  1345
#  Clusterizando bloco  1346
#  Clusterizando bloco  1347
#  Clusterizando bloco  1348
#  Clusterizando bloco  1349
#  Clusterizando bloco  1350
#  Clusterizando bloco  1351
#  Clusterizando bloco  1352
#  Clusterizando bloco  1353
#  Clusterizando bloco  1354
#  Clusterizando bloco  1355
#  Clusterizando bloco  1356
#  Clusterizando bloco  1357
#  Clusterizando bloco  1358
#  Clusterizando bloco  1359
#  Clusterizando bloco  1360
#  Clusterizando bloco  1361
#  Clusterizando bloco  1362
#  Clusterizando bloco  1363
#  Clusterizando bloco  1364
#  Clusterizando bloco  1365
#  Clusterizando bloco  1366
#  Clusterizando bloco  1367
#  Clusterizando bloco  1368
#  Clusterizando bloco  1369
#  Clusterizando bloco  1370
#  Clusterizando bloco  1371
#  Clusterizando bloco  1372
#  Clusterizando bloco  1373
#  Clusterizando bloco  1374
#  Clusterizando bloco  1375
#  Clusterizando bloco  1376
#  Clusterizando bloco  1377
#  Clusterizando bloco  1378
#  Clusterizando bloco  1379
#  Clusterizando bloco  1380
#  Clusterizando bloco  1381
#  Clusterizando bloco  1382
#  Clusterizando bloco  1383
#  Clusterizando bloco  1384
#  Clusterizando bloco  1385
#  Clusterizando bloco  1386
#  Clusterizando bloco  1387
#  Clusterizando bloco  1388
#  Clusterizando bloco  1389
#  Clusterizando bloco  1390
#  Clusterizando bloco  1391
#  Clusterizando bloco  1392
#  Clusterizando bloco  1393
#  Clusterizando bloco  1394
#  Clusterizando bloco  1395
#  Clusterizando bloco  1396
#  Clusterizando bloco  1397
#  Clusterizando bloco  1398
#  Clusterizando bloco  1399
#  Clusterizando bloco  1400
#  Clusterizando bloco  1401
#  Clusterizando bloco  1402
#  Clusterizando bloco  1403
#  Clusterizando bloco  1404
#  Clusterizando bloco  1405
#  Clusterizando bloco  1406
#  Clusterizando bloco  1407
#  Clusterizando bloco  1408
#  Clusterizando bloco  1409
#  Clusterizando bloco  1410
#  Clusterizando bloco  1411
#  Clusterizando bloco  1412
#  Clusterizando bloco  1413
#  Clusterizando bloco  1414
#  Clusterizando bloco  1415
#  Clusterizando bloco  1416
#  Clusterizando bloco  1417
#  Clusterizando bloco  1418
#  Clusterizando bloco  1419
#  Clusterizando bloco  1420
#  Clusterizando bloco  1421
#  Clusterizando bloco  1422
#  Clusterizando bloco  1423
#  Clusterizando bloco  1424
#  Clusterizando bloco  1425
#  Clusterizando bloco  1426
#  Clusterizando bloco  1427
#  Clusterizando bloco  1428
#  Clusterizando bloco  1429
#  Clusterizando bloco  1430
#  Clusterizando bloco  1431
#  Clusterizando bloco  1432
#  Clusterizando bloco  1433
#  Clusterizando bloco  1434
#  Clusterizando bloco  1435
#  Clusterizando bloco  1436
#  Clusterizando bloco  1437
#  Clusterizando bloco  1438
#  Clusterizando bloco  1439
#  Clusterizando bloco  1440
#  Clusterizando bloco  1441
#  Clusterizando bloco  1442
#  Clusterizando bloco  1443
#  Clusterizando bloco  1444
#  Clusterizando bloco  1445
#  Clusterizando bloco  1446
#  Clusterizando bloco  1447
#  Clusterizando bloco  1448
#  Clusterizando bloco  1449
#  Clusterizando bloco  1450
#  Clusterizando bloco  1451
#  Clusterizando bloco  1452
#  Clusterizando bloco  1453
#  Clusterizando bloco  1454
#  Clusterizando bloco  1455
#  Clusterizando bloco  1456
#  Clusterizando bloco  1457
#  Clusterizando bloco  1458
#  Clusterizando bloco  1459
#  Clusterizando bloco  1460
#  Clusterizando bloco  1461
#  Clusterizando bloco  1462
#  Clusterizando bloco  1463
#  Clusterizando bloco  1464
#  Clusterizando bloco  1465
#  Clusterizando bloco  1466
#  Clusterizando bloco  1467
#  Clusterizando bloco  1468
#  Clusterizando bloco  1469
#  Clusterizando bloco  1470
#  Clusterizando bloco  1471
#  Clusterizando bloco  1472
#  Clusterizando bloco  1473
#  Clusterizando bloco  1474
#  Clusterizando bloco  1475
#  Clusterizando bloco  1476
#  Clusterizando bloco  1477
#  Clusterizando bloco  1478
#  Clusterizando bloco  1479
#  Clusterizando bloco  1480
#  Clusterizando bloco  1481
#  Clusterizando bloco  1482
#  Clusterizando bloco  1483
#  Clusterizando bloco  1484
#  Clusterizando bloco  1485
#  Clusterizando bloco  1486
#  Clusterizando bloco  1487
#  Clusterizando bloco  1488
#  Clusterizando bloco  1489
#  Clusterizando bloco  1490
#  Clusterizando bloco  1491
#  Clusterizando bloco  1492
#  Clusterizando bloco  1493
#  Clusterizando bloco  1494
#  Clusterizando bloco  1495
#  Clusterizando bloco  1496
#  Clusterizando bloco  1497
#  Clusterizando bloco  1498
#  Clusterizando bloco  1499
#  Clusterizando bloco  1500
#  Clusterizando bloco  1501
#  Clusterizando bloco  1502
#  Clusterizando bloco  1503
#  Clusterizando bloco  1504
#  Clusterizando bloco  1505
#  Clusterizando bloco  1506
#  Clusterizando bloco  1507
#  Clusterizando bloco  1508
#  Clusterizando bloco  1509
#  Clusterizando bloco  1510
#  Clusterizando bloco  1511
#  Clusterizando bloco  1512
#  Clusterizando bloco  1513
#  Clusterizando bloco  1514
#  Clusterizando bloco  1515
#  Clusterizando bloco  1516
#  Clusterizando bloco  1517
#  Clusterizando bloco  1518
#  Clusterizando bloco  1519
#  Clusterizando bloco  1520
#  Clusterizando bloco  1521
#  Clusterizando bloco  1522
#  Clusterizando bloco  1523
#  Clusterizando bloco  1524
#  Clusterizando bloco  1525
#  Clusterizando bloco  1526
#  Clusterizando bloco  1527
#  Clusterizando bloco  1528
#  Clusterizando bloco  1529
#  Clusterizando bloco  1530
#  Clusterizando bloco  1531
#  Clusterizando bloco  1532
#  Clusterizando bloco  1533
#  Clusterizando bloco  1534
#  Clusterizando bloco  1535
#  Clusterizando bloco  1536
#  Clusterizando bloco  1537
#  Clusterizando bloco  1538
#  Clusterizando bloco  1539
#  Clusterizando bloco  1540
#  Clusterizando bloco  1541
#  Clusterizando bloco  1542
#  Clusterizando bloco  1543
#  Clusterizando bloco  1544
#  Clusterizando bloco  1545
#  Clusterizando bloco  1546
#  Clusterizando bloco  1547
#  Clusterizando bloco  1548
#  Clusterizando bloco  1549
#  Clusterizando bloco  1550
#  Clusterizando bloco  1551
#  Clusterizando bloco  1552
#  Clusterizando bloco  1553
#  Clusterizando bloco  1554
#  Clusterizando bloco  1555
#  Clusterizando bloco  1556
#  Clusterizando bloco  1557
#  Clusterizando bloco  1558
#  Clusterizando bloco  1559
#  Clusterizando bloco  1560
#  Clusterizando bloco  1561
#  Clusterizando bloco  1562
#  Clusterizando bloco  1563
#  Clusterizando bloco  1564
#  Clusterizando bloco  1565
#  Clusterizando bloco  1566
#  Clusterizando bloco  1567
#  Clusterizando bloco  1568
#  Clusterizando bloco  1569
#  Clusterizando bloco  1570
#  Clusterizando bloco  1571
#  Clusterizando bloco  1572
#  Clusterizando bloco  1573
#  Clusterizando bloco  1574
#  Clusterizando bloco  1575
#  Clusterizando bloco  1576
#  Clusterizando bloco  1577
#  Clusterizando bloco  1578
#  Clusterizando bloco  1579
#  Clusterizando bloco  1580
#  Clusterizando bloco  1581
#  Clusterizando bloco  1582
#  Clusterizando bloco  1583
#  Clusterizando bloco  1584
#  Clusterizando bloco  1585
#  Clusterizando bloco  1586
#  Clusterizando bloco  1587
#  Clusterizando bloco  1588
#  Clusterizando bloco  1589
#  Clusterizando bloco  1590
#  Clusterizando bloco  1591
#  Clusterizando bloco  1592
#  Clusterizando bloco  1593
#  Clusterizando bloco  1594
#  Clusterizando bloco  1595
#  Clusterizando bloco  1596
#  Clusterizando bloco  1597
#  Clusterizando bloco  1598
#  Clusterizando bloco  1599
#  Clusterizando bloco  1600
#  Clusterizando bloco  1601
#  Clusterizando bloco  1602
#  Clusterizando bloco  1603
#  Clusterizando bloco  1604
#  Clusterizando bloco  1605
#  Clusterizando bloco  1606
#  Clusterizando bloco  1607
#  Clusterizando bloco  1608
#  Clusterizando bloco  1609
#  Clusterizando bloco  1610
#  Clusterizando bloco  1611
#  Clusterizando bloco  1612
#  Clusterizando bloco  1613
#  Clusterizando bloco  1614
#  Clusterizando bloco  1615
#  Clusterizando bloco  1616
#  Clusterizando bloco  1617
#  Clusterizando bloco  1618
#  Clusterizando bloco  1619
#  Clusterizando bloco  1620
#  Clusterizando bloco  1621
#  Clusterizando bloco  1622
#  Clusterizando bloco  1623
#  Clusterizando bloco  1624
#  Clusterizando bloco  1625
#  Clusterizando bloco  1626
#  Clusterizando bloco  1627
#  Clusterizando bloco  1628
#  Clusterizando bloco  1629
#  Clusterizando bloco  1630
#  Clusterizando bloco  1631
#  Clusterizando bloco  1632
#  Clusterizando bloco  1633
#  Clusterizando bloco  1634
#  Clusterizando bloco  1635
#  Clusterizando bloco  1636
#  Clusterizando bloco  1637
#  Clusterizando bloco  1638
#  Clusterizando bloco  1639
#  Clusterizando bloco  1640
#  Clusterizando bloco  1641
#  Clusterizando bloco  1642
#  Clusterizando bloco  1643
#  Clusterizando bloco  1644
#  Clusterizando bloco  1645
#  Clusterizando bloco  1646
#  Clusterizando bloco  1647
#  Clusterizando bloco  1648
#  Clusterizando bloco  1649
#  Clusterizando bloco  1650
#  Clusterizando bloco  1651
#  Clusterizando bloco  1652
#  Clusterizando bloco  1653
#  Clusterizando bloco  1654
#  Clusterizando bloco  1655
#  Clusterizando bloco  1656
#  Clusterizando bloco  1657
#  Clusterizando bloco  1658
#  Clusterizando bloco  1659
#  Clusterizando bloco  1660
#  Clusterizando bloco  1661
#  Clusterizando bloco  1662
#  Clusterizando bloco  1663
#  Clusterizando bloco  1664
#  Clusterizando bloco  1665
#  Clusterizando bloco  1666
#  Clusterizando bloco  1667
#  Clusterizando bloco  1668
#  Clusterizando bloco  1669
#  Clusterizando bloco  1670
#  Clusterizando bloco  1671
#  Clusterizando bloco  1672
#  Clusterizando bloco  1673
#  Clusterizando bloco  1674
#  Clusterizando bloco  1675
#  Clusterizando bloco  1676
#  Clusterizando bloco  1677
#  Clusterizando bloco  1678
#  Clusterizando bloco  1679
#  Clusterizando bloco  1680
#  Clusterizando bloco  1681
#  Clusterizando bloco  1682
#  Clusterizando bloco  1683
#  Clusterizando bloco  1684
#  Clusterizando bloco  1685
#  Clusterizando bloco  1686
#  Clusterizando bloco  1687
#  Clusterizando bloco  1688
#  Clusterizando bloco  1689
#  Clusterizando bloco  1690
#  Clusterizando bloco  1691
#  Clusterizando bloco  1692
#  Clusterizando bloco  1693
#  Clusterizando bloco  1694
#  Clusterizando bloco  1695
#  Clusterizando bloco  1696
#  Clusterizando bloco  1697
#  Clusterizando bloco  1698
#  Clusterizando bloco  1699
#  Clusterizando bloco  1700
#  Clusterizando bloco  1701
#  Clusterizando bloco  1702
#  Clusterizando bloco  1703
#  Clusterizando bloco  1704
#  Clusterizando bloco  1705
#  Clusterizando bloco  1706
#  Clusterizando bloco  1707
#  Clusterizando bloco  1708
#  Clusterizando bloco  1709
#  Clusterizando bloco  1710
#  Clusterizando bloco  1711
#  Clusterizando bloco  1712
#  Clusterizando bloco  1713
#  Clusterizando bloco  1714
#  Clusterizando bloco  1715
#  Clusterizando bloco  1716
#  Clusterizando bloco  1717
#  Clusterizando bloco  1718
#  Clusterizando bloco  1719
#  Clusterizando bloco  1720
#  Clusterizando bloco  1721
#  Clusterizando bloco  1722
#  Clusterizando bloco  1723
#  Clusterizando bloco  1724
#  Clusterizando bloco  1725
#  Clusterizando bloco  1726
#  Clusterizando bloco  1727
#  Clusterizando bloco  1728
#  Clusterizando bloco  1729
#  Clusterizando bloco  1730
#  Clusterizando bloco  1731
#  Clusterizando bloco  1732
#  Clusterizando bloco  1733
#  Clusterizando bloco  1734
#  Clusterizando bloco  1735
#  Clusterizando bloco  1736
#  Clusterizando bloco  1737
#  Clusterizando bloco  1738
#  Clusterizando bloco  1739
#  Clusterizando bloco  1740
#  Clusterizando bloco  1741
#  Clusterizando bloco  1742
#  Clusterizando bloco  1743
#  Clusterizando bloco  1744
#  Clusterizando bloco  1745
#  Clusterizando bloco  1746
#  Clusterizando bloco  1747
#  Clusterizando bloco  1748
#  Clusterizando bloco  1749
#  Clusterizando bloco  1750
#  Clusterizando bloco  1751
#  Clusterizando bloco  1752
#  Clusterizando bloco  1753
#  Clusterizando bloco  1754
#  Clusterizando bloco  1755
#  Clusterizando bloco  1756
#  Clusterizando bloco  1757
#  Clusterizando bloco  1758
#  Clusterizando bloco  1759
#  Clusterizando bloco  1760
#  Clusterizando bloco  1761
#  Clusterizando bloco  1762
#  Clusterizando bloco  1763
#  Clusterizando bloco  1764
#  Clusterizando bloco  1765
#  Clusterizando bloco  1766
#  Clusterizando bloco  1767
#  Clusterizando bloco  1768
#  Clusterizando bloco  1769
#  Clusterizando bloco  1770
#  Clusterizando bloco  1771
#  Clusterizando bloco  1772
#  Clusterizando bloco  1773
#  Clusterizando bloco  1774
#  Clusterizando bloco  1775
#  Clusterizando bloco  1776
#  Clusterizando bloco  1777
#  Clusterizando bloco  1778
#  Clusterizando bloco  1779
#  Clusterizando bloco  1780
#  Clusterizando bloco  1781
#  Clusterizando bloco  1782
#  Clusterizando bloco  1783
#  Clusterizando bloco  1784
#  Clusterizando bloco  1785
#  Clusterizando bloco  1786
#  Clusterizando bloco  1787
#  Clusterizando bloco  1788
#  Clusterizando bloco  1789
#  Clusterizando bloco  1790
#  Clusterizando bloco  1791
#  Clusterizando bloco  1792
#  Clusterizando bloco  1793
#  Clusterizando bloco  1794
#  Clusterizando bloco  1795
#  Clusterizando bloco  1796
#  Clusterizando bloco  1797
#  Clusterizando bloco  1798
#  Clusterizando bloco  1799
#  Clusterizando bloco  1800
#  Clusterizando bloco  1801
#  Clusterizando bloco  1802
#  Clusterizando bloco  1803
#  Clusterizando bloco  1804
#  Clusterizando bloco  1805
#  Clusterizando bloco  1806
#  Clusterizando bloco  1807
#  Clusterizando bloco  1808
#  Clusterizando bloco  1809
#  Clusterizando bloco  1810
#  Clusterizando bloco  1811
# ...
#
#   BLOCO 3008 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3009 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3010 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 66.66666666666666 %
#
#   BLOCO 3011 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3012 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3013 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3014 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3015 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3016 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3017 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3018 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3019 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3020 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 63.33333333333333 %
#
#   BLOCO 3021 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3022 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3023 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3024 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3025 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3026 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3027 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3028 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3029 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3030 (teve 6 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 72.22222222222221 %
#
#   BLOCO 3031 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3032 (teve 4 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3033 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3034 (teve 6 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 94.44444444444443 %
#
#   BLOCO 3035 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3036 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3037 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3038 (teve 12 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 80.55555555555554 %
#
#   BLOCO 3039 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3040 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 62.5 %
#
#   BLOCO 3041 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 80.0 %
#
#   BLOCO 3042 (teve 3 clusters): Precisão em relação ao bloco: 66.66666666666666 %. -- Precisão em relação a base: 43.333333333333336 %
#
#   BLOCO 3043 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 88.88888888888889 %
#
#   BLOCO 3044 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3045 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3046 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3047 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3048 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 40.0 %
#
#   BLOCO 3049 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 83.33333333333334 %
#
#   BLOCO 3050 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3051 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3052 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 33.33333333333333 %
#
#   BLOCO 3053 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3054 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 20.0 %
#
#   BLOCO 3055 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 88.88888888888889 %
#
#   BLOCO 3056 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3057 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3058 (teve 5 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 53.333333333333336 %
#
#   BLOCO 3059 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 62.5 %
#
#   BLOCO 3060 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3061 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 66.66666666666666 %
#
#   BLOCO 3062 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3063 (teve 3 clusters): Precisão em relação ao bloco: 66.66666666666666 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3064 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3065 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3066 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 91.66666666666666 %
#
#   BLOCO 3067 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 66.66666666666666 %
#
#   BLOCO 3068 (teve 11 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 58.03030303030303 %
#
#   BLOCO 3069 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 58.33333333333333 %
#
#   BLOCO 3070 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3071 (teve 8 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3072 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3073 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3074 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3075 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 65.0 %
#
#   BLOCO 3076 (teve 5 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 76.66666666666666 %
#
#   BLOCO 3077 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3078 (teve 2 clusters): Precisão em relação ao bloco: 50.0 %. -- Precisão em relação a base: 33.33333333333333 %
#
#   BLOCO 3079 (teve 3 clusters): Precisão em relação ao bloco: 66.66666666666666 %. -- Precisão em relação a base: 49.99999999999999 %
#
#   BLOCO 3080 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 70.0 %
#
#   BLOCO 3081 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3082 (teve 2 clusters): Precisão em relação ao bloco: 50.0 %. -- Precisão em relação a base: 37.5 %
#
#   BLOCO 3083 (teve 4 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 79.16666666666666 %
#
#   BLOCO 3084 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 83.33333333333334 %
#
#   BLOCO 3085 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 76.66666666666666 %
#
#   BLOCO 3086 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3087 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3088 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3089 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3090 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 66.66666666666666 %
#
#   BLOCO 3091 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3092 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 66.66666666666666 %
#
#   BLOCO 3093 (teve 4 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 87.5 %
#
#   BLOCO 3094 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3095 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3096 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3097 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3098 (teve 4 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 54.166666666666664 %
#
#   BLOCO 3099 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3100 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3101 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 41.666666666666664 %
#
#   BLOCO 3102 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3103 (teve 3 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 38.888888888888886 %
#
#   BLOCO 3104 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3105 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3106 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3107 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 80.0 %
#
#   BLOCO 3108 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3109 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3110 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 20.0 %
#
#   BLOCO 3111 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3112 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 41.666666666666664 %
#
#   BLOCO 3113 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 62.5 %
#
#   BLOCO 3114 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3115 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3116 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 40.0 %
#
#   BLOCO 3117 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 40.0 %
#
#   BLOCO 3118 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 20.0 %
#
#   BLOCO 3119 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3120 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 33.33333333333333 %
#
#   BLOCO 3121 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 66.66666666666666 %
#
#   BLOCO 3122 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3123 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 33.33333333333333 %
#
#   BLOCO 3124 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 33.33333333333333 %
#
#   BLOCO 3125 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 60.0 %
#
#   BLOCO 3126 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3127 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3128 (teve 2 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
#   BLOCO 3129 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3130 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3131 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3132 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3133 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 20.0 %
#
#   BLOCO 3134 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3135 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 100.0 %
#
#   BLOCO 3136 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3137 (teve 2 clusters): Precisão em relação ao bloco: 50.0 %. -- Precisão em relação a base: 40.0 %
#
#   BLOCO 3138 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.0 %
#
#   BLOCO 3139 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 25.0 %
#
#   BLOCO 3140 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 20.0 %
#
#   BLOCO 3141 (teve 1 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 75.0 %
#
# Relacao Bloco:  99.00611651476028  %
# Relacao Base Toda:  71.55763532787788  %
#
# ------------------------------------------------------------------
#
# Precisão:
#       Relacao Bloco  Relacao Base Toda
# 0         96.396396          43.558559
# 1        100.000000          60.650407
# 2        100.000000          83.333333
# 3        100.000000          62.500000
# 4        100.000000          71.428571
# ...             ...                ...
# 3137      50.000000          40.000000
# 3138     100.000000          50.000000
# 3139     100.000000          25.000000
# 3140     100.000000          20.000000
# 3141     100.000000          75.000000
#
# [3142 rows x 2 columns]

# %%
for i, block_clusters in enumerate(clusters):
    print("CLUSTERS DO BLOCK ", i)
    for cluster_key in block_clusters.keys():
      print('>>>> CLUSTER: ' , cluster_key)
      for i, item in enumerate(block_clusters[cluster_key]):
        print('>>>> ',item['TID'], item['title'], item['artist'],  )
      print()
    print('-'*100)
# Out:
# CLUSTERS DO BLOCK  0
# >>>> CLUSTER:  2
# >>>>  2 007 [unknown]
#
# >>>> CLUSTER:  11
# >>>>  11  Anathema
#
# >>>> CLUSTER:  18
# >>>>  18 00-1
# >>>>  4304 001 Blue Cafe
# >>>>  5048
# >>>>  5110 001- () Twins
# >>>>  5427  ÐÐºÐ²Ð°Ñ€Ð¸ÑƒÐ¼
# >>>>  6093 00-1 [unknown]
# >>>>  6406  Xpembunuhx
# >>>>  9044 001-
# >>>>  10149 001-
# >>>>  11049 001-
# >>>>  15937 001-
# >>>>  16140 001 Kings of Convenience
# >>>>  19320 001- SE7EN
#
# >>>> CLUSTER:  30
# >>>>  30 011-
# >>>>  182 011-
# >>>>  12019
# >>>>  16606 011-
#
# >>>> CLUSTER:  73
# >>>>  73  Stephan Sechi
#
# >>>> CLUSTER:  133
# >>>>  133 *** Wind Hearse
# >>>>  12196
#
# >>>> CLUSTER:  202
# >>>>  202 Ð Ð¾Ð´Ð¸Ð½Ð° ÐžÐ»ÑŒÐ³Ð° ÐÑ€ÐµÑ„ÑŒÐµÐ²Ð° Ð¸ Ð³Ñ€ÑƒÐ¿Ð¿Ð° "ÐšÐ¾Ð²Ñ‡ÐµÐ³"
#
# >>>> CLUSTER:  228
# >>>>  228 031-
#
# >>>> CLUSTER:  288
# >>>>  288 #9 BEAT-CRUSADERS
# >>>>  3422
#
# >>>> CLUSTER:  462
# >>>>  462 013--
# >>>>  14373 003-
# >>>>  19334 013-
#
# >>>> CLUSTER:  474
# >>>>  474 12 Dead
# >>>>  7346 12
#
# >>>> CLUSTER:  683
# >>>>  683 005
# >>>>  1355 005-
# >>>>  1867  DragonForce
# >>>>  2489 005-
# >>>>  5372 005-
# >>>>  7029 005-
# >>>>  10912 005-    Jack Action
# >>>>  11703 005-
# >>>>  19346 005 Bettye LaVette
#
# >>>> CLUSTER:  831
# >>>>  831 19841031 U2
#
# >>>> CLUSTER:  937
# >>>>  937  J.K. Rowling
#
# >>>> CLUSTER:  953
# >>>>  953 Ð›Ð¾Ð»Ð° Ð”Ð¼Ð¸Ñ‚Ñ€Ð¸Ð¹ ÐœÐ°Ð»Ð¸ÐºÐ¾Ð²
#
# >>>> CLUSTER:  1055
# >>>>  1055 4 275
# >>>>  11921 4
#
# >>>> CLUSTER:  1113
# >>>>  1113 002-   Schizo
#
# >>>> CLUSTER:  1182
# >>>>  1182 010-  starring
# >>>>  1350 010-~ Uratsakidogi
# >>>>  3232 010-
# >>>>  7086 010-
#
# >>>> CLUSTER:  1315
# >>>>  1315 006-
# >>>>  1755  Carmen Miranda
# >>>>  2355 006-
# >>>>  3222 006- deadman
# >>>>  4041 006-
# >>>>  10777 006-
# >>>>  11006 006-  Uma2rmaH
# >>>>  12281 006 Sidney Bechet
# >>>>  13445  Sunny Day Service
# >>>>  16876 006-    Atra Hora
#
# >>>> CLUSTER:  1370
# >>>>  1370  å¹¡è°·å°šå²
#
# >>>> CLUSTER:  1479
# >>>>  1479 009 03:10
#
# >>>> CLUSTER:  1562
# >>>>  1562  Sokak KÃ¶pekleri
# >>>>  2126
# >>>>  8237 007-
# >>>>  19229 007-
#
# >>>> CLUSTER:  1835
# >>>>  1835  Enrico Sono
# >>>>  10617
#
# >>>> CLUSTER:  2153
# >>>>  2153
#
# >>>> CLUSTER:  2155
# >>>>  2155 020-
#
# >>>> CLUSTER:  2183
# >>>>  2183 003-   n.a.
# >>>>  3833 003-
# >>>>  5576 003-
# >>>>  5742 004-/
# >>>>  10208 003-
# >>>>  14705 00-
#
# >>>> CLUSTER:  2215
# >>>>  2215  Esham
#
# >>>> CLUSTER:  2244
# >>>>  2244 02:28 Tant Strul
#
# >>>> CLUSTER:  2317
# >>>>  2317 002- Pizzicato Five
#
# >>>> CLUSTER:  2500
# >>>>  2500  Brody Dalle
#
# >>>> CLUSTER:  2518
# >>>>  2518 03:47 Get It
#
# >>>> CLUSTER:  2665
# >>>>  2665  The Last Atlant
#
# >>>> CLUSTER:  2926
# >>>>  2926 012-
# >>>>  8440 012-
# >>>>  9271 012
# >>>>  16530 12 244
# >>>>  16733 012-
#
# >>>> CLUSTER:  2966
# >>>>  2966 002-... Infetu
# >>>>  5248 002-
# >>>>  5306 002
# >>>>  11279 002- in cremonica mono+
# >>>>  14027 002-
#
# >>>> CLUSTER:  3089
# >>>>  3089 015- - ""
# >>>>  5644 005-
# >>>>  17584 005-
#
# >>>> CLUSTER:  3441
# >>>>  3441 1 165
# >>>>  4588 1 195
# >>>>  7987 1 4m 31sec
# >>>>  11021 1 3.867
#
# >>>> CLUSTER:  3463
# >>>>  3463  Tea Leaf Green
#
# >>>> CLUSTER:  3602
# >>>>  3602 6 65
#
# >>>> CLUSTER:  4027
# >>>>  4027 8994 Johann Sebastian Bach
#
# >>>> CLUSTER:  4147
# >>>>  4147 3-630 Ian Vine
# >>>>  14928 36-30 Ian Vine
#
# >>>> CLUSTER:  4157
# >>>>  4157  Sean Terrington Wright
#
# >>>> CLUSTER:  4177
# >>>>  4177 020-  [unknown]
# >>>>  15003 020-
#
# >>>> CLUSTER:  4202
# >>>>  4202 010- ALFEE
#
# >>>> CLUSTER:  4211
# >>>>  4211 24
# >>>>  6538 24 John Robbins
#
# >>>> CLUSTER:  4406
# >>>>  4406 017-
# >>>>  5250  Frank Sinatra
#
# >>>> CLUSTER:  4421
# >>>>  4421
# >>>>  5004 2 Johann Sebastian Bach
# >>>>  7143 080- dj scotch egg
# >>>>  7770 008- Kagrra,
# >>>>  8944 008- Galneryus
# >>>>  14280  Aural Planet
# >>>>  14401 008 Frankie Armstrong
# >>>>  14651 04:06 Joseph Haydn
# >>>>  15005 008-
# >>>>  17188 008-
# >>>>  18300 8 Darryl Way
#
# >>>> CLUSTER:  4755
# >>>>  4755 016-
# >>>>  7033  T. Brinda & T. Mukta
# >>>>  15307 016-  Jin Nakamura
# >>>>  16402 016-11  ....
#
# >>>> CLUSTER:  4824
# >>>>  4824 12 6.183
#
# >>>> CLUSTER:  5115
# >>>>  5115 1389
# >>>>  13879  Vitamin C
#
# >>>> CLUSTER:  5512
# >>>>  5512 8 3m 21sec
#
# >>>> CLUSTER:  5965
# >>>>  5965 002-100001 1010101 OpenBSD
# >>>>  11388 100001 1010101 OpenBSD
#
# >>>> CLUSTER:  5999
# >>>>  5999 004-"" (, , , )
# >>>>  7471 004-
# >>>>  7559 004-     ""
# >>>>  8205 005-2
# >>>>  11048 004-
# >>>>  12562 004-
# >>>>  13253 002-
# >>>>  14810 004-
#
# >>>> CLUSTER:  6261
# >>>>  6261  Les Collabos
#
# >>>> CLUSTER:  6633
# >>>>  6633 004 Zwotackter
#
# >>>> CLUSTER:  6901
# >>>>  6901 1.6 KK Null
#
# >>>> CLUSTER:  6965
# >>>>  6965    - .
#
# >>>> CLUSTER:  6984
# >>>>  6984 23 3m 2sec
#
# >>>> CLUSTER:  7012
# >>>>  7012 9 132253
#
# >>>> CLUSTER:  7036
# >>>>  7036
#
# >>>> CLUSTER:  7043
# >>>>  7043 Ð¢Ð¾Ð¼Ð° ÐšÐ°Ð±Ð°Ñ€Ðµ-Ð´ÑƒÑÑ‚ "ÐÐºÐ°Ð´ÐµÐ¼Ð¸Ñ"
#
# >>>> CLUSTER:  7146
# >>>>  7146
#
# >>>> CLUSTER:  7364
# >>>>  7364 ... Inffetu
# >>>>  19063 ... - ...
#
# >>>> CLUSTER:  7481
# >>>>  7481
#
# >>>> CLUSTER:  7540
# >>>>  7540 003-
# >>>>  7659 004-
# >>>>  14438  Ballalouda
#
# >>>> CLUSTER:  7701
# >>>>  7701 Ð¡Ð²Ð¾Ð±Ð¾Ð´Ð° Ð”Ð¶Ð°Ð½ ÐºÑƒ
# >>>>  17492 Ð¡Ð²Ð¾Ð±Ð¾Ð´Ð° Ð”Ð¶Ð°Ð½ ÐºÑƒ
#
# >>>> CLUSTER:  7717
# >>>>  7717  godheadSilo
#
# >>>> CLUSTER:  7935
# >>>>  7935 011 03:10
#
# >>>> CLUSTER:  8206
# >>>>  8206  John Katzenbach
#
# >>>> CLUSTER:  8281
# >>>>  8281 40 7000
#
# >>>> CLUSTER:  8312
# >>>>  8312 004 05:46
#
# >>>> CLUSTER:  8429
# >>>>  8429 010-
#
# >>>> CLUSTER:  8901
# >>>>  8901  Son of Rust
#
# >>>> CLUSTER:  8975
# >>>>  8975 013 [unknown]
# >>>>  11034 013 Paul Paljett
#
# >>>> CLUSTER:  9081
# >>>>  9081 2 InnerWish
#
# >>>> CLUSTER:  9241
# >>>>  9241 10 3m 37sec
# >>>>  12409 10 3m 16sec
#
# >>>> CLUSTER:  9423
# >>>>  9423  Just Like Ammy
#
# >>>> CLUSTER:  9453
# >>>>  9453 003-,
#
# >>>> CLUSTER:  9478
# >>>>  9478
#
# >>>> CLUSTER:  9545
# >>>>  9545  Camden Stoddard
#
# >>>> CLUSTER:  9644
# >>>>  9644  Dirtie Blonde
# >>>>  16809 009-
# >>>>  18731 009-
#
# >>>> CLUSTER:  9700
# >>>>  9700  Bob & Tom
#
# >>>> CLUSTER:  9788
# >>>>  9788
#
# >>>> CLUSTER:  9817
# >>>>  9817 009-
# >>>>  19081 009-
#
# >>>> CLUSTER:  9864
# >>>>  9864 024-
#
# >>>> CLUSTER:  9866
# >>>>  9866 0133-2012
#
# >>>> CLUSTER:  9975
# >>>>  9975  Soul Coughing
#
# >>>> CLUSTER:  10010
# >>>>  10010 6 216
# >>>>  17706 6 1184
#
# >>>> CLUSTER:  10059
# >>>>  10059 911 Skadanks
#
# >>>> CLUSTER:  10632
# >>>>  10632 1 å¤§æ±Ÿåƒé‡Œ
#
# >>>> CLUSTER:  10708
# >>>>  10708 003-  My Victory
# >>>>  15920 003-
#
# >>>> CLUSTER:  10728
# >>>>  10728  Carola
#
# >>>> CLUSTER:  10820
# >>>>  10820 122504 Luigi Boccherini
#
# >>>> CLUSTER:  10940
# >>>>  10940 025-
#
# >>>> CLUSTER:  11622
# >>>>  11622 023-
#
# >>>> CLUSTER:  11728
# >>>>  11728  Jean NÃ©plin & Individual State
#
# >>>> CLUSTER:  11849
# >>>>  11849  Clarion Brass Choir
#
# >>>> CLUSTER:  11947
# >>>>  11947  M. Whitwell
#
# >>>> CLUSTER:  11984
# >>>>  11984 005-99 Toto
#
# >>>> CLUSTER:  12010
# >>>>  12010 037 04:26
#
# >>>> CLUSTER:  12302
# >>>>  12302  Nicosas de Angelis
# >>>>  17205 010-
# >>>>  17809 010-
#
# >>>> CLUSTER:  12382
# >>>>  12382  Cool Hipnoise
#
# >>>> CLUSTER:  12501
# >>>>  12501  Incubus
#
# >>>> CLUSTER:  12506
# >>>>  12506  Can Atilla
#
# >>>> CLUSTER:  12656
# >>>>  12656 15 279
#
# >>>> CLUSTER:  12741
# >>>>  12741 2001 Atombombpocketknife
#
# >>>> CLUSTER:  12829
# >>>>  12829  En-Sonic
#
# >>>> CLUSTER:  12962
# >>>>  12962 019-
#
# >>>> CLUSTER:  13188
# >>>>  13188 2 3m 56sec
#
# >>>> CLUSTER:  13999
# >>>>  13999 011 T-Bone
# >>>>  17943 011-
#
# >>>> CLUSTER:  14063
# >>>>  14063  David Oliver
#
# >>>> CLUSTER:  14132
# >>>>  14132 20000429 Aube
#
# >>>> CLUSTER:  14462
# >>>>  14462
#
# >>>> CLUSTER:  14599
# >>>>  14599 1 2m 28sec
# >>>>  19067 1 Mandaaly
#
# >>>> CLUSTER:  14742
# >>>>  14742 018-
#
# >>>> CLUSTER:  14760
# >>>>  14760 2 3.8n83
# >>>>  17702 2 298
#
# >>>> CLUSTER:  14771
# >>>>  14771 4.233 Mack 10
#
# >>>> CLUSTER:  14845
# >>>>  14845 100
#
# >>>> CLUSTER:  15232
# >>>>  15232 ×¢×œ ×”×§×¦×” (× ×©××¨ ×¨×§ ×œ×¨×•×¥) × ×§×ž×ª ×”×˜×¨×§×˜×•×¨
#
# >>>> CLUSTER:  15245
# >>>>  15245 5 Hal Leoanrd
# >>>>  17775 5 Hal Leonard
#
# >>>> CLUSTER:  15267
# >>>>  15267  Dezrok
#
# >>>> CLUSTER:  15328
# >>>>  15328 7 1.968
#
# >>>> CLUSTER:  15407
# >>>>  15407 009- Altan Urag
#
# >>>> CLUSTER:  15432
# >>>>  15432 009-  I.H.N.A.B.T.B.
#
# >>>> CLUSTER:  15469
# >>>>  15469
#
# >>>> CLUSTER:  15648
# >>>>  15648 17 180000
#
# >>>> CLUSTER:  15721
# >>>>  15721  FÃ¼hrs & FrÃ¶hling
#
# >>>> CLUSTER:  15898
# >>>>  15898 002-002
#
# >>>> CLUSTER:  16116
# >>>>  16116  Poi Dog Pondering
#
# >>>> CLUSTER:  16184
# >>>>  16184 001- GRAANRODEO
#
# >>>> CLUSTER:  16208
# >>>>  16208  Earth and Fire
# >>>>  18680 015-
#
# >>>> CLUSTER:  16220
# >>>>  16220  Peter Schilling
#
# >>>> CLUSTER:  16464
# >>>>  16464 005-1999 Jolly Joker and the Plastic Beatles of the Universe
# >>>>  18633 1999 Jolly Joker and the Plastic Beatles of the Universe
#
# >>>> CLUSTER:  16508
# >>>>  16508  Tanya Tucker
#
# >>>> CLUSTER:  16840
# >>>>  16840 14 Frank Emilio Flynn
#
# >>>> CLUSTER:  16886
# >>>>  16886
#
# >>>> CLUSTER:  17417
# >>>>  17417 4 Lester Flatt & Earl Scurggs
#
# >>>> CLUSTER:  17838
# >>>>  17838  uAtofans
#
# >>>> CLUSTER:  17910
# >>>>  17910 11 240440
#
# >>>> CLUSTER:  17949
# >>>>  17949 003 03:04
#
# >>>> CLUSTER:  18253
# >>>>  18253  Dr. Feelgood
#
# >>>> CLUSTER:  18541
# >>>>  18541 007-
# >>>>  18763 007-
#
# >>>> CLUSTER:  18699
# >>>>  18699 003- Warsoul
#
# >>>> CLUSTER:  18742
# >>>>  18742 008 02:59
#
# >>>> CLUSTER:  18790
# >>>>  18790
#
# >>>> CLUSTER:  18863
# >>>>  18863 7 4.387
#
# >>>> CLUSTER:  19012
# >>>>  19012 11 256640
#
# >>>> CLUSTER:  19086
# >>>>  19086  Mendoza Dance Parti
#
# >>>> CLUSTER:  19184
# >>>>  19184  Freddie Hubbard
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  1
# >>>> CLUSTER:  1336
# >>>>  1336 åº¾æ¾„æ…¶ - æ¯”æ°¸é é‚„è¦ä¹…
#
# >>>> CLUSTER:  1499
# >>>>  1499 ×™×•×ª×¨ ×‘×¨×•×¨ (××—×¨×™ ×œ×™×œ×” ×©×œ ×¨×¢×©) ×“×•×“×• ×˜×¡×”
# >>>>  15951 ×™×•×ª×¨ ×‘×¨×•×¨ ×“×•×“×• ×˜×¡×”
#
# >>>> CLUSTER:  1862
# >>>>  1862 ã‚«ã‚«ãƒªã‚³æ‘ è¿‘è—¤æµ©æ²»
#
# >>>> CLUSTER:  1953
# >>>>  1953 ã‚½ãƒ•ãƒˆã‚¯ãƒªãƒ¼ãƒ  - ã‚³ã‚¢ãƒ©ã“ã‚“ã‚“ã«ã¡ã¯
#
# >>>> CLUSTER:  1969
# >>>>  1969 å®¶ II å‘¨è¯å¥
# >>>>  7660 å‘¨è¯å¥ - å®¶ II
#
# >>>> CLUSTER:  1998
# >>>>  1998 å¦¥å” è”¡ä¾æž—
#
# >>>> CLUSTER:  2047
# >>>>  2047 ã‚­ãƒ¼ãƒœãƒ¼ãƒ‰ãƒ»ã‚¤ãƒ³ãƒˆãƒ­ãƒ€ã‚¯ã‚·ãƒ§ãƒ³ æ”¾èª²å¾Œãƒ†ã‚£ãƒ¼ã‚¿ã‚¤ãƒ
#
# >>>> CLUSTER:  3410
# >>>>  3410 â™  Marilyn Manson
#
# >>>> CLUSTER:  4156
# >>>>  4156 ãƒ‡ã‚¿ãƒ©ãƒ¡ãªæ®‹åƒ GRANRODEO
# >>>>  4890 ãƒ‡ã‚¿ãƒ©ãƒ¡ãªæ®‹åƒ GRANROqDEO
#
# >>>> CLUSTER:  4229
# >>>>  4229 0A3 03:14
#
# >>>> CLUSTER:  4491
# >>>>  4491 ã‚¬ã‚¹ãƒˆ - æœªå…¬é–‹æ›²2
# >>>>  19221 æœªå…¬é–‹æ›²2 ã‚¬ã‚¹ãƒˆ
#
# >>>> CLUSTER:  4855
# >>>>  4855 ãƒ“ãƒªãƒ¼ãƒ»ãƒãƒ³ãƒãƒ³ - ãƒŸãƒ‰ãƒªãƒ¼ãƒŒ
# >>>>  5579 ãƒŸãƒ‰ãƒªãƒ¼ãƒŒ ãƒ“ãƒªãƒ¼ãƒ»ãƒãƒ³ãƒãƒ³
# >>>>  12527 ãƒŸãƒ‰ãƒªãƒ¼ãƒŒ (ãƒ“ãƒªãƒ¼ãƒ»ãƒãƒ³ãƒãƒ³ ãƒ„ã‚¤ãƒ³ãƒ»ãƒ™ã‚¹ãƒˆ) ãƒ“ãƒªãƒ¼ãƒ»ãƒãƒ³ãƒãƒ³
#
# >>>> CLUSTER:  6651
# >>>>  6651 å¤§åˆ‡ãªã‚¯ãƒ©ã‚¹ãƒ¡ã‚¤ãƒˆ - ã‚ã¡ã‚ƒãƒ¢ãƒ†å§”å“¡é•· ã‚ã¡ã‚ƒãƒ’ãƒƒãƒˆæ›²é›†â‘  [unknown]
#
# >>>> CLUSTER:  6703
# >>>>  6703 åˆ†è£‚ (æµ®èº) çŽ‹è²
# >>>>  7060 åˆ†è£‚ çŽ‹è²
# >>>>  16335 åˆ†è£‚ - æµ®èº çŽ‹è²
#
# >>>> CLUSTER:  8825
# >>>>  8825 ãƒœãƒ˜ãƒŸã‚¢ãƒ³ è‘›åŸŽãƒ¦ã‚­
#
# >>>> CLUSTER:  9145
# >>>>  9145 ×©×¨×™×ª ×—×“×“ - ×ª×©×ª×•×§ ×ª×©×ª×•×§
#
# >>>> CLUSTER:  9250
# >>>>  9250 ã‚¹ã‚¯ãƒªãƒ¼ãƒ³ã®å¥³ Boris
#
# >>>> CLUSTER:  9252
# >>>>  9252 ã‚ˆãªã‚‰ã‚’ã‚‚ã†åº¦ å°¾å´Žç´€ä¸–å½¦
#
# >>>> CLUSTER:  10236
# >>>>  10236 å†¤å®¶ å¼µåœ‹æ¦®
#
# >>>> CLUSTER:  10269
# >>>>  10269 æ„›ã®èª¿ã¹ win a sheep free
#
# >>>> CLUSTER:  10647
# >>>>  10647 ã­ãŒã„ - ä¸ƒå¤•å¤œæƒ³æ›²ã€€æ‘ä¸‹å­è”µæœ€é«˜é¸æ›²é›†ã€€å…¶ã®å£± æ‘ä¸‹å­è”µ
#
# >>>> CLUSTER:  11058
# >>>>  11058 ã‚ã‚‹ã‚¿ãƒ³ã‚´å¼¾ã ã¸ã®å“€æ­Œ: III. ã‚¨ãƒ”ãƒ­ãƒ¼ã‚° MÃ¡ximo DDiego Pujol
#
# >>>> CLUSTER:  12358
# >>>>  12358 å‰ã¸ ãƒ ãƒƒã‚¯
# >>>>  17476 å‰ã¸ - è‘¬ãƒ©è¬³ ãƒ ãƒƒã‚¯
#
# >>>> CLUSTER:  13101
# >>>>  13101 å·äº•æ†²æ¬¡ - ã‚«ãƒ¬ãƒ¼å±‹ã®ã‚¤ãƒ³ãƒ‰äºº
#
# >>>> CLUSTER:  13221
# >>>>  13221 ã‚µãƒ³ãƒ‡ãƒ¼ãƒ¢ãƒ¼ãƒ‹ãƒ³ã‚° ãã‚‹ã‚Š
#
# >>>> CLUSTER:  13500
# >>>>  13500 ãƒ¬ãƒ‡ã‚£ãƒ¼ãƒ»ã‚ªãƒ–ãƒ»ã‚¶ãƒ»ãƒ•ãƒ©ãƒ¯ãƒ¼ã‚º - ãƒ—ãƒ©ã‚·ãƒ¼ãƒœ Placebo
#
# >>>> CLUSTER:  13549
# >>>>  13549 ã‚¢ãƒ³ãƒ‹ãƒ¥ã‚¤ã¡ã‚‡ã†ã¡ã‚‡ è±šä¹™å¥³
#
# >>>> CLUSTER:  13560
# >>>>  13560 0A1 Georges Brassens
#
# >>>> CLUSTER:  13653
# >>>>  13653 å…„å¼Ÿ (æƒ…ä¹‰) ä»»è´¤é½
#
# >>>> CLUSTER:  13957
# >>>>  13957 å½± æ± é ¼åºƒ Jin Nakamura ä¸­æ‘ä¸­
#
# >>>> CLUSTER:  14081
# >>>>  14081 ã‚¢ã‚¢ãƒ³ã‚³ãƒ¼ãƒ« æ–°æ—¥æœ¬ãƒ•ã‚£ãƒ«ãƒãƒ¼ãƒ¢ãƒ‹ãƒ¼äº¤éŸ¿æ¥½å›£
#
# >>>> CLUSTER:  14824
# >>>>  14824 ã‚ˆã„ã“ã®ãƒãƒ¤ãƒ†ã‹ã‚‹ãŸã€Œã¤ã€ ç¶¾å´Žãƒãƒ¤ãƒ† starring ç™½çŸ³æ¶¼å­
#
# >>>> CLUSTER:  15213
# >>>>  15213 ä¼æ›¸é³© æ£®ç”°ç«¥å­
#
# >>>> CLUSTER:  16389
# >>>>  16389 ãƒ›ãƒ¼ãƒŸãƒ¼ã®éŸ³ï¼ˆãƒ›ãƒ¼ãƒŸãƒ¼ï¼‰ [unknown]
#
# >>>> CLUSTER:  16696
# >>>>  16696 æ±äº¬äº‹å¤‰ - ä½“
#
# >>>> CLUSTER:  16748
# >>>>  16748 ãƒ´ã‚£ãƒ‰ãƒ¼ãƒ« - åƒ•ã€åƒ•ã€‚
#
# >>>> CLUSTER:  16923
# >>>>  16923 0A5-
#
# >>>> CLUSTER:  17203
# >>>>  17203 ã„ã¤ã‚‚ã®é¢¨æ™¯ rain book
#
# >>>> CLUSTER:  17813
# >>>>  17813 æ‹ã¯å¤‰ã˜ã‚ƒãªã„ CASCADE
#
# >>>> CLUSTER:  18306
# >>>>  18306 æ—§ãæƒ³ã„ ç§¦ä¿®
#
# >>>> CLUSTER:  18657
# >>>>  18657 å‰ä¸– é™³æ…§Fç³
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  2
# >>>> CLUSTER:  14043
# >>>>  14043 007-A.O.V. Hell's Kitchen
#
# >>>> CLUSTER:  15999
# >>>>  15999 Ã–Ã¶pÃ¤ev Urmas Alender
#
# >>>> CLUSTER:  17681
# >>>>  17681 å­å®ˆæ­Œ op. 16-1 (ã‚°ãƒ©ãƒ³ãƒ‰ãƒ»ãƒªã‚µã‚¤ã‚¿ãƒ«) ãƒãƒ£ã‚¤ã‚³ãƒ•ã‚¹ã‚­ãƒ¼/ãƒ©ãƒ•ãƒžãƒ‹ãƒŽãƒ•ç·¨æ›²
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3
# >>>> CLUSTER:  7069
# >>>>  7069 ABC For Kdis - Jamaica Farewell
#
# >>>> CLUSTER:  7248
# >>>>  7248 Apes of Wrath - Toolkit
#
# >>>> CLUSTER:  10990
# >>>>  10990 AÅ¡ pas savo giminÄ—lÄ™ - Dievo Å¾irgai, laimÄ—s ratai Spanxti
#
# >>>> CLUSTER:  12734
# >>>>  12734 015-A Box for Leslie Jack Van Poll
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  4
# >>>> CLUSTER:  265
# >>>>  265 002-Abie Stracie Like a Tim
#
# >>>> CLUSTER:  1754
# >>>>  1754 Auf, schicke dich recht feierlich, Wq 249: Recitativ "Wohin mein Auge blickt" (Tenor) - Edition Bach Carl Philipp Emanuel Carl Philipp Emanuel Bach
# >>>>  4997 Auf, schicke dich recht feierlich, Wq 249: Recitativ "Wohin mein Auge blickt" (Tenor) (Edition Bach Carl Philipp Emanuel) Carl Philipp Emanuel Bach
# >>>>  10039 Auf, schicke dich recht feierlich, Wq 249: Recitativ "Wohin mein Auge blickt" (Tenor) Carl Philipp Emanuel Bach
# >>>>  18706 012-Auf, schicke dich recht feierlich, Wq 249: Recitativ "Wohin mein Auge blickt" (Tenor) Carl Philipp Emanuel Bach
#
# >>>> CLUSTER:  1813
# >>>>  1813 A Positive Life - Pleidean Communication
#
# >>>> CLUSTER:  3929
# >>>>  3929 Abhijit Pohankar - Manmohini (Enchantress)
#
# >>>> CLUSTER:  4222
# >>>>  4222 Abschied (AugenBlicke) Illuminate
#
# >>>> CLUSTER:  8954
# >>>>  8954 A Postcard From Lahaina - Long Prairie River Kepa Kettunen
#
# >>>> CLUSTER:  12053
# >>>>  12053 ãƒ¡ãƒ­ã‚­ãƒ¥ã‚¢ - Pop Step Jump!
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  5
# >>>> CLUSTER:  384
# >>>>  384 Apopocalyps - Flickorna i VÃ¥ran Stad
#
# >>>> CLUSTER:  5181
# >>>>  5181 005-Avec le temps Dalida
# >>>>  16977 Avec le temps - Talents, Volume 2 Dalida
#
# >>>> CLUSTER:  6770
# >>>>  6770 æ°´å½©ã‚­ãƒ£ãƒ³ãƒ‡ã‚£ãƒ¼ (off vocal) marble
#
# >>>> CLUSTER:  6903
# >>>>  6903 Apocalyptic Worldview in Judaism (Apocalypse: Controversies and Meaning in Western History) Professor Craig R. Koester
#
# >>>> CLUSTER:  9172
# >>>>  9172 Absolum -G No Rush
#
# >>>> CLUSTER:  11637
# >>>>  11637 Absolute Perfection - Greensleeves Sampler 2 Pato Banton
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  6
# >>>> CLUSTER:  92
# >>>>  92 Apache (instrumental) (On Stage / In Studio) On Stage / In Studio
# >>>>  127 Apache (instrumental) Agents & Vesa Haaja
#
# >>>> CLUSTER:  1435
# >>>>  1435 Abschnitt 14 (Percy Jackson: Diebe im Olymp) Rick Riordan gelesen von Marius ClarÃ©n
#
# >>>> CLUSTER:  1907
# >>>>  1907 001-Apache (introo) The Shadows
# >>>>  11337 Apache (intro) - The Final Tour Shadows
# >>>>  16050 Apache (intro) (The Final Tour) Shadows
# >>>>  18008 Apache (intro) The SShadows
#
# >>>> CLUSTER:  5188
# >>>>  5188 Avskum - The Massacre in Fallujah
#
# >>>> CLUSTER:  7823
# >>>>  7823 Abschnitt 6 - Der Zauberer von Oz Lyman Frank Baum gelesen von Senta Berger
# >>>>  8706 AbschnWitt 6 Lyman Frank Bau gelesen von Senta Berger
#
# >>>> CLUSTER:  10314
# >>>>  10314 A Pequena ColmÃ©ia de Dinossauros - HÃ­brido Velhos e Usados
# >>>>  16583 010-A Pequena Colmeia de Dinossauros Velhos e Usados
#
# >>>> CLUSTER:  12240
# >>>>  12240 aPssion Flower l- In Motion Heath Brothers
#
# >>>> CLUSTER:  12933
# >>>>  12933 Abismo Skore
# >>>>  15387 Abismo (ColisÃ£o) Skore
#
# >>>> CLUSTER:  16839
# >>>>  16839 å±±æ ¹ãƒŸãƒãƒ« - Poison Moth
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  7
# >>>> CLUSTER:  16148
# >>>>  16148 Apex (ZReborn EP) Absent Without Leave
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  8
# >>>> CLUSTER:  12952
# >>>>  12952 About You Invocal
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  9
# >>>> CLUSTER:  855
# >>>>  855 Abida Parveen - Ghazal (Hakim Nasser)
#
# >>>> CLUSTER:  13567
# >>>>  13567 A Beautiful Mind - A Beautiful Mind LP Butch-Clancy
#
# >>>> CLUSTER:  17673
# >>>>  17673 Abby Dobson - Music Box - Intro
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  10
# >>>> CLUSTER:  1085
# >>>>  1085 About You (Simple Things) Invocal
# >>>>  17084 About You - Simple Things Invocal
#
# >>>> CLUSTER:  3473
# >>>>  3473 Above The Clouds Fast Distance vs. Dimensionn
#
# >>>> CLUSTER:  6661
# >>>>  6661 ã„ã¨ã†ã‹ãªã“ - Fetishism Ark (off Vocal)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  11
# >>>> CLUSTER:  5911
# >>>>  5911 Above Them - Thank You
#
# >>>> CLUSTER:  7899
# >>>>  7899 Abide With Me Phil Keaggy
#
# >>>> CLUSTER:  10308
# >>>>  10308 Ã‡a fait mal - On trace la route : L Live Christophe MaÃ©
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  12
# >>>> CLUSTER:  731
# >>>>  731 After All - Ace Ian Van Dahl
# >>>>  10629 003-After All Ian Van Dahl
#
# >>>> CLUSTER:  842
# >>>>  842 After You Get What You Want, You Don't Wan tIt Marilyn Monroe
# >>>>  7584 After You Get What You Want, You Don't Want It (Marilyn Monroe) Marilyn Monroe
#
# >>>> CLUSTER:  1239
# >>>>  1239 æ‹ã¯å¤‰ã˜ã‚ƒãªã„ (BUTTERFLY LIMITED EXPRESS) CASCADE
#
# >>>> CLUSTER:  1427
# >>>>  1427 A Better Day Multicyde
# >>>>  2837 A Better Day (Multiplicity) Multicyde
# >>>>  4111 A Better Day - Multiplicity Multicyde
# >>>>  11885 005-A Better Day Multicyde
#
# >>>> CLUSTER:  2807
# >>>>  2807 After - Bleak Output Noon
#
# >>>> CLUSTER:  3186
# >>>>  3186 0A2-Better to Be LIAM Fin
#
# >>>> CLUSTER:  3304
# >>>>  3304 Afterburn Chris Salt
#
# >>>> CLUSTER:  5753
# >>>>  5753 About a Dream - Mississippi Studios Live: Volume One Steve Forbert
# >>>>  8861 About a Dream (Mississippi Studios Live: Volume One) Steve Forbert
# >>>>  16547 013-About a Dream Steve Forbert
#
# >>>> CLUSTER:  9143
# >>>>  9143 Afterglow (Escape) Contagious Orgasm
# >>>>  10805 Afterglow - Escape Contagiou Orgasm
#
# >>>> CLUSTER:  15885
# >>>>  15885 ãƒ‹ã‚± featuring neko - Return of the throneï¼ˆLong Ver.ï¼‰
#
# >>>> CLUSTER:  16619
# >>>>  16619 AFTERSCHOOL - Yes No Yes
#
# >>>> CLUSTER:  18278
# >>>>  18278 After Hours (Better Days) Marcin Nowakowski
#
# >>>> CLUSTER:  18682
# >>>>  18682 AP11008 (The Return to the Acid Planet) FunkstÃ¶rung
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  13
# >>>> CLUSTER:  17505
# >>>>  17505 001-Above All Helen Jane Long
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  14
# >>>> CLUSTER:  700
# >>>>  700 0A3-Pool of Piranhas Hammers Rule
#
# >>>> CLUSTER:  1676
# >>>>  1676 Appleblim - Mystikal Warrior
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  15
# >>>> CLUSTER:  3173
# >>>>  3173 Apologize - The Voice Of Holland - The Songs Charlotte Ten Brink
# >>>>  3904 Apologize Charlotte Ten Brink
#
# >>>> CLUSTER:  6073
# >>>>  6073 Apoplexy å´Žå…ƒä»
# >>>>  10063 Apoplexy - Final Fantasy Tactics å´Žå…ƒä»
# >>>>  16929 037-Apoplexy
#
# >>>> CLUSTER:  6424
# >>>>  6424 Apologies - Bavarian Drinking Songs Wat Tyler
#
# >>>> CLUSTER:  9078
# >>>>  9078 006-Apologies Appease
#
# >>>> CLUSTER:  9582
# >>>>  9582 Appleknockers Flophouse (Hotel Grolloo) Cuby + Blizzards feat. Tineke Schoenmaker
#
# >>>> CLUSTER:  12313
# >>>>  12313 Aphilas - Aesthetics
#
# >>>> CLUSTER:  14800
# >>>>  14800 Applause Edmundo Ros and His Orchestra
#
# >>>> CLUSTER:  15997
# >>>>  15997 Abfallsozialprodukt - Papst
#
# >>>> CLUSTER:  17007
# >>>>  17007 Apollo 440 - Krupa (Escape From New York mix)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  16
# >>>> CLUSTER:  1046
# >>>>  1046 Appel Ã  tous les fidÃ¨les (Le ragga Ã§a l'fait) SaÃ¯ SaÃ¯
# >>>>  18200 Appel Ã  tous les fidÃ¨les SaÃ¯ SaÃ¯
#
# >>>> CLUSTER:  4497
# >>>>  4497 Apply Directly to the Forehead (Wal*Mart-Approved Music) Hathaway Family Plot
#
# >>>> CLUSTER:  9806
# >>>>  9806 ä¹¾æ¯ã‚¢ãƒ¯ãƒ¼ - FLOW THE MAX ï¼ï¼ï¼ FLOW
#
# >>>> CLUSTER:  12622
# >>>>  12622 A Ballad To Chuang Tzu (The Magic Of Martial Arts) Oliver Shanti
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  17
# >>>> CLUSTER:  1398
# >>>>  1398 Avalon (IntÃ©grale, Volume 3: "Djangology") Quintette du Hot Club de France
#
# >>>> CLUSTER:  2893
# >>>>  2893 Avalanche - Overnight Sensation
#
# >>>> CLUSTER:  3014
# >>>>  3014 A volume of Titan Go King's (Gut's Idol) Titan Go King's
# >>>>  4523 A volume of Titan Go King's Titaan Go King's
# >>>>  17779 007-A Volume of Titan Go King's Titan Go King's
#
# >>>> CLUSTER:  10484
# >>>>  10484 A Fullness of Light in Your Soul (Sapphie) Richard Youngs
# >>>>  15157 A Fullness of Light in Your Soul Richard Youngs
#
# >>>> CLUSTER:  10699
# >>>>  10699 Avalonia (An Ephemeral World) Patrick Rondat
#
# >>>> CLUSTER:  10983
# >>>>  10983 â€œBalance of Terrorâ€: Romulan Theme (M22) - Star Trek: The Original Series Soundtrack Collection Fred Steineer
#
# >>>> CLUSTER:  13578
# >>>>  13578 Abbey Lincoln - Let Up
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  18
# >>>> CLUSTER:  279
# >>>>  279 A Vava Inouva 2 - Deux rives, un rÃªve Idir
#
# >>>> CLUSTER:  2101
# >>>>  2101 Auf einem persischen Markt - Die Berliner spielen Salonmusik Albert William KetÃ¨lbey
#
# >>>> CLUSTER:  3245
# >>>>  3245 ãƒ‘ãƒ³ãƒ‰ãƒ© - Vuena Vista ã‚¸ãƒ³
#
# >>>> CLUSTER:  7301
# >>>>  7301 Abana Ba Nasery - Omwana Wa Mberi Nesiekhoira
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  19
# >>>> CLUSTER:  16039
# >>>>  16039 ã‚¹ã‚¯ãƒªãƒ¼ãƒ³ã®å¥³ (Pink) Boris
#
# >>>> CLUSTER:  17000
# >>>>  17000 002-Apenas hay rivales L.UR.
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  20
# >>>> CLUSTER:  1895
# >>>>  1895 Avenida Jukkis Uotila
# >>>>  18502 Avenida Jukkis Uotila
#
# >>>> CLUSTER:  3776
# >>>>  3776 Avanti Avanti - Jij Hoort Bij Mij Anita de Hoop
# >>>>  11893 010A-vanti Avanti Anita de Hoop
# >>>>  13344 Avanti Avanti Anita de Hoop
# >>>>  18882 Avanti Avanti (Jij Hoort Bij Mij) Anita de Hoop
#
# >>>> CLUSTER:  5640
# >>>>  5640 Abomination's Child - Paradise of Eternal Darkness Torment
#
# >>>> CLUSTER:  8639
# >>>>  8639 â€œBy Any Other Nameâ€: Finale / Thematic Playoff - Star Trek: The Original Series Soundtrack Collection Fred Steiner
#
# >>>> CLUSTER:  15057
# >>>>  15057 Avundsjuk Nanne GrÃ¶nwall
#
# >>>> CLUSTER:  17782
# >>>>  17782 Appendage (ISDN) Future Sound of London
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  21
# >>>> CLUSTER:  8347
# >>>>  8347 Ave Maria (Chiptune Mix) - Merry Pixmas 8 Bit Weapon
#
# >>>> CLUSTER:  10915
# >>>>  10915 A2B - Mercury Rising Rae & Christian feat. Mystro, Masta Ace & Pete Simpson
#
# >>>> CLUSTER:  17793
# >>>>  17793 Ave Maria (BoÅ¾iÄna Å¾elja) Oto Pestner
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  22
# >>>> CLUSTER:  2084
# >>>>  2084 A Fair Affair (Je T'aime) Misty Oldland
# >>>>  5285 A Fair Affair (Je T'aime) (More Music 2) Misty Oldland
#
# >>>> CLUSTER:  2587
# >>>>  2587 A Perfect Stillness (c) (edn link) Brian D. Gulland
#
# >>>> CLUSTER:  16300
# >>>>  16300 001-A Perfect Day Roger Whittaker
# >>>>  17440 A Perfect Day Roger Whittaker
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  23
# >>>> CLUSTER:  2473
# >>>>  2473 007-African Herbsman Bob Marley
# >>>>  4604 African Herbsman - The Best of the Upsetter Years 1970-1971 (Bob Marley vs. Lee Scratch Perry) Bob Marley
# >>>>  13812 African Herbsman
#
# >>>> CLUSTER:  3400
# >>>>  3400 001-Apres une lecture du dante : fantasia quasi sonata Lise-de-la-Salle
# >>>>  3791 AprÃ¨s une lecture du dante : fantasia quasi sonata - Liszt Lise de la Salle
# >>>>  7957 AprÃ¨s une lecture du dante : fantasia quasi sonata (Liszt) Lise de la Salle
#
# >>>> CLUSTER:  4453
# >>>>  4453 A Froggy Day (Bar Classics 3) George Gershwin
#
# >>>> CLUSTER:  5719
# >>>>  5719 African Descendent I-Roy
#
# >>>> CLUSTER:  6587
# >>>>  6587 A Very Good Reason - MÃºsica Viva Mozar Terra
#
# >>>> CLUSTER:  7344
# >>>>  7344 Africa Unite - Soffici sapori
#
# >>>> CLUSTER:  9348
# >>>>  9348 Auberge Platinum Collection) Chris Rea
#
# >>>> CLUSTER:  10103
# >>>>  10103 006-Apressadinho Genario
# >>>>  11097 Apressadinho (ForrÃ³ de Vanguarda) GenÃ¡rio
# >>>>  19173 Apressadinho GenÃƒÂ¡rio
#
# >>>> CLUSTER:  11963
# >>>>  11963 Afriganda (full mix) Barry Dean S hear
#
# >>>> CLUSTER:  13025
# >>>>  13025 å†¤å®¶ (Four Seasons) å¼µåœ‹æ¦®
# >>>>  14736 å†¤å®¶ - Four Seasons å¼µåœ‹æ¦®
#
# >>>> CLUSTER:  14547
# >>>>  14547 A Praise Chorus - Press Play Blipster
#
# >>>> CLUSTER:  15825
# >>>>  15825 å³¶å®®ãˆã„å­ - verge
#
# >>>> CLUSTER:  19191
# >>>>  19191 Afrika interludo (Afrika Kompilo) JoMo
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  24
# >>>> CLUSTER:  1394
# >>>>  1394 Abortion Black Uhuru
#
# >>>> CLUSTER:  2163
# >>>>  2163 Ã‰bredj fel! mOrsi
# >>>>  14758 Ã‰bredj fel! (Egy csepp mÃ©z) Orsi
#
# >>>> CLUSTER:  6835
# >>>>  6835 Aborted - Eructations of Carnal Artistry
#
# >>>> CLUSTER:  16364
# >>>>  16364 Aborted - Purity of Perversion
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  25
# >>>> CLUSTER:  8389
# >>>>  8389 Ãœberall auf der Welt - Die Deutsche Single Hitparade 1972 Freddy Breck
#
# >>>> CLUSTER:  9747
# >>>>  9747 April in Paris - Jazz Piquant Tina May & Tony Coe
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  26
# >>>> CLUSTER:  9921
# >>>>  9921 A Framer The Bilge Festival
#
# >>>> CLUSTER:  10614
# >>>>  10614 Abram - 12 gramos
#
# >>>> CLUSTER:  13489
# >>>>  13489 Away from Me Puddle of Mudd
#
# >>>> CLUSTER:  16514
# >>>>  16514 034-Abraham Lincoln, George Patton  War Professor J. Rufus Fears
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  27
# >>>> CLUSTER:  150
# >>>>  150 å²©å´Žæ–‡ç´€ - æ·±æµ·ã®ç²¾
# >>>>  1759 æ·±æµ·ã®ç²¾ å²©å´Žæ–‡ç´€
# >>>>  13726 æ·±æµ·ã®ç²¾ (ã‚ã¾ãˆãªã„ã§ã‚ˆã£!! ã•ã‚“ã¨ã‚‰å†¬ç›¤) å²©å´Žæ–‡ç´€
#
# >>>> CLUSTER:  304
# >>>>  304 ãƒ”ãƒ³ã¼ã‘ (æ¸‹æ»žã¬ã‘ã¿ã¡ãªã—) é«˜ç”°æ¢¢æž
#
# >>>> CLUSTER:  490
# >>>>  490 ã‚ªãƒ³ãƒªãƒ¼ãƒ»ãƒžãƒ³ - ã‚µã‚¯ãƒ©å¤§æˆ¦ å¸åŠ‡æ­Œè¬¡å…¨é›† ã‚¿ãƒãƒãƒŠãƒ»ãƒžãƒªã‚¢
#
# >>>> CLUSTER:  498
# >>>>  498 ãƒŸ ã‚¹ãƒ»ã‚¢ãƒ³ãƒŠ the BOOGIE JACK
#
# >>>> CLUSTER:  1047
# >>>>  1047 ã‚ã‚Šã®ã¾ã¾ SE7EN
# >>>>  13947 ã‚ã‚Šã®ã¾ã¾ SE7EN
#
# >>>> CLUSTER:  1195
# >>>>  1195 ãƒãƒ­ã‚¹ ï¼ˆã‚­ã‚¯ãƒ©ãƒ‡ã‚¹è«¸å³¶ãƒŠã‚¯ã‚½ã‚¹å³¶ã®ã‚«ãƒƒãƒ—ãƒ«ãƒ»ãƒ€ãƒ³ã‚¹ï¼‰ (ã‚®ãƒªã‚·ãƒ£ã®æ°‘æ—éŸ³æ¥½) [unknown]
# >>>>  6724 ãƒãƒ­ã‚¹ ï¼ˆã‚­ã‚¯ãƒ©ãƒ‡ã‚¹è«¸å³¶ãƒŠã‚¯ã‚½ã‚¹å³¶ã®ã‚«ãƒƒãƒ—ãƒ«ãƒ»ãƒ€ãƒ³ã‚¹ï¼‰ - ã‚®ãƒªã‚·ãƒ£ã®æ°‘æ—éŸ³æ¥½ [unkown]
#
# >>>> CLUSTER:  1826
# >>>>  1826 å¯æ„›ä¸å¯æ„› (å¦Sèªžç‰ˆ) unk.
# >>>>  15268 å¯æ„›ä¸å¯æ„› (å¦èªžç‰ˆ) (æ¡è©±å¦èªž) WoM13041744
#
# >>>> CLUSTER:  1854
# >>>>  1854 æ–°å®¿ãƒ–ãƒ«ãƒ¼ã‚¹ - ç²¾é¸ç›¤ æ˜­å’Œã®æµè¡Œæ­Œ æ‰‡ã²ã‚å­
#
# >>>> CLUSTER:  1999
# >>>>  1999 ã‚·ã‚§ãƒ¼ãƒ³ãƒ»ãƒˆã‚¥ãƒ«ãƒ¼ã‚¹ ï¼ˆ4ã‚¹ãƒ­ãƒ¼ã€2ã‚¯ã‚¤ãƒƒã‚¯ãƒ»ã‚¹ãƒ†ãƒƒãƒ—ã‚¹ï¼‰ï¼šãƒ•ã‚£ãƒƒã‚¹ãƒ«ãƒ»ã‚ªã‚¦ã‚¢ãƒ¼ãƒ»ã‚¶ãƒ»ãƒ¬ã‚¤ãƒ–ãƒ»ã‚ªã‚¨ãƒƒãƒˆã€œãƒžã‚®ãƒ¼ãƒ»ã‚­ãƒ£ãƒ¡ãƒ­ãƒ³ - ã‚¹ã‚³ãƒƒãƒˆãƒ©ãƒ³ãƒ‰ã®ãƒã‚°ãƒ‘ã‚¤ãƒ—â€”ãƒã‚¤ãƒ©ãƒ³ãƒ‰ã®é¢¨ ãƒ“ãƒ«ãƒ»ã‚¯ãƒ¬ãƒ¡ãƒ³ãƒˆ
#
# >>>> CLUSTER:  2061
# >>>>  2061 å‰ç”°æœ‰ç´€ - ã‚µãƒ©ãƒ³ãƒ˜æ„›ã€œã—ã¦ã‚‹ã€œ
#
# >>>> CLUSTER:  3054
# >>>>  3054 å®¶ II - ç¾…å¤§ä½‘è‡ªé¸è¼¯ å‘¨è¯å¥
#
# >>>> CLUSTER:  3072
# >>>>  3072 ãƒ¬ãƒ™ãƒ« - ãƒãƒ´ã‚¡ãƒŠã‚¤ã‚¹ãƒ‡ãƒ¼ UNICORN
#
# >>>> CLUSTER:  3549
# >>>>  3549 å¦¥å” (èŠ±è´è¶) è”¡ä¾æž—
# >>>>  14045 å¦¥å” - èŠ±è´è¶ è”¡ä¾æž—
#
# >>>> CLUSTER:  3987
# >>>>  3987 ã‚ã‚‹ã‚¿ãƒ³ã‚´å¼¾ãã¸ã®å“€æ­Œ: III. ã‚¨ãƒ”ãƒ­ãƒ¼ã‚° (ã‚«ãƒ´ã‚¡ãƒ†ã‚£ãƒ¼ãƒŠ) MÃ¡ximo Diego Pujol
#
# >>>> CLUSTER:  4348
# >>>>  4348 æœªå…¬é–‹æ›²2 (ãƒ­ãƒ­ãƒŠã®ã‚¢ãƒˆãƒªã‚¨ï½žã‚¢ãƒ¼ãƒ©ãƒ³ãƒ‰ã®éŒ¬é‡‘è¡“å£«ï½ž ãƒ“ã‚¸ãƒ¥ã‚¢ãƒ«ã‚¢ãƒ¼ãƒˆãƒ–ãƒƒã‚¯) ã‚¬ã‚¹ãƒˆ
# >>>>  16888 æœªå…¬é–‹æ›²2 - ãƒ­ãƒ­ãƒŠã®ã‚¢ãƒˆãƒªã‚¨ï½žã‚¢ãƒ¼ãƒ©ãƒ³ãƒ‰ã®éŒ¬é‡‘è¡“å£«ï½ž ãƒ“ã‚¸ãƒ¥ã‚¢ãƒ«ã‚¢ãƒ¼ãƒˆãƒ–ãƒƒã‚¯ ã‚¬ã‚¹ãƒˆ
#
# >>>> CLUSTER:  4547
# >>>>  4547 ã¶ã¡ãƒ‘ãƒ³ãƒ€ - ã‚¹ãƒ¼ãƒ‘ãƒ¼ãƒ¢ã‚°ãƒ¼"åœ°åº•ç‰¹æ€¥ã‚¹ãƒ¼ãƒ‘ãƒ¼ãƒ¢ã‚°ãƒ¼"
#
# >>>> CLUSTER:  4699
# >>>>  4699 å¼µåœ‹æ¦® & é»ƒè€€æ˜Ž - å¤œæœ‰æ‰€å¤¢
#
# >>>> CLUSTER:  5793
# >>>>  5793 å°æ¤‹ä½³ - ç§ã¯é€ã‚Šé¢¨
#
# >>>> CLUSTER:  5818
# >>>>  5818 ä¸Šæµ·ã ã‚ˆã‚Š - ç²¾é¸ç›¤ æ˜­å’Œã®æµè¡Œæ­Œ ä¸Šæ•åŽŸ
# >>>>  18507 ä¸Šæµ·ã ã‚ˆã‚Š ä¸ŠåŽŸæ•
#
# >>>> CLUSTER:  6296
# >>>>  6296 å’æ¥­ - å›žå¸°ç·š å°¾å´Žè±Š
#
# >>>> CLUSTER:  6751
# >>>>  6751 å¤§æ±Ÿåƒé‡Œ - ãƒ¯ãƒ©ãƒ“ãƒ¼ã¬ãŽã™ã¦ã¦
# >>>>  10570 ãƒ¯ãƒ©ãƒ“ãƒ¼ã¬ãŽã™ã¦ã¦ å¤§æ±Ÿåƒé‡Œ
# >>>>  18391 ãƒ¯ãƒ©ãƒ“ãƒ¼ã¬ãŽã™ã¦ã¦ (WAKU WAKU) æ±Ÿå¤§åƒé‡Œ
#
# >>>> CLUSTER:  6814
# >>>>  6814 å°é¦–ã‚’ã‹ã—ã’ã¦ ï½ž ãã®ï¼’ (ãƒ¡ãƒ«ãƒ«ã®ã‚¢ãƒˆãƒªã‚¨ï½žã‚¢ãƒ¼ãƒ©ãƒ³ãƒ‰ã®éŒ¬é‡‘è¡“å£«3 ã‚ªãƒªã‚¸ãƒŠãƒ«ã‚µã‚¦ãƒ³ãƒ‰ãƒˆãƒ©ãƒƒã‚¯) ã‚¬ã‚¹ãƒˆ
#
# >>>> CLUSTER:  7448
# >>>>  7448 ãƒãƒ å¤ªéƒŽãƒ»ã‚¶ãƒ»ãƒ ãƒ¼ãƒ“ãƒ¼ å²©å´Žå…ƒæ˜¯
#
# >>>> CLUSTER:  7558
# >>>>  7558 åœ‹åºœç”°ãƒžãƒªå­ - æœ¬æ°—ã«ã—ãªã„ã§
#
# >>>> CLUSTER:  7886
# >>>>  7886 ã‚°ãƒ©ãƒ“ãƒ†ã‚£ - æ´žçªŸç‰©èªž é–‹ç™ºå®¤Pixel
# >>>>  10502 ã‚°ãƒ©ãƒ“ãƒ†ã‚£ (æ´žçªŸç‰©èªž) é–‹ç™ºå®¤Pixel
#
# >>>> CLUSTER:  8256
# >>>>  8256 ä¸–ç•Œå¿«æ¨‚ (æ„Ÿè¦ºå®Œç¾Ž) æž—æ†¶è“®
# >>>>  9312 ä¸–ç•Œå¿«æ¨‚ æž—æ†¶è“®
#
# >>>> CLUSTER:  8292
# >>>>  8292 å…‰å®—ä¿¡å‰ - åœ°çƒã¯äººç‰©é™³åˆ—å®¤
#
# >>>> CLUSTER:  8450
# >>>>  8450 ã‚«ã‚«ãƒ¼ãƒ»ã‚»ãƒ¬ã‚¯ãƒˆ - æ¹¾å²¸ãƒŸãƒƒãƒ‰ãƒŠã‚¤ãƒˆ ã‚µã‚¦ãƒ³ãƒ‰ãƒˆãƒ©ãƒƒã‚¯ å¤ä»£ç¥ä¸‰
#
# >>>> CLUSTER:  9085
# >>>>  9085 ã“ã“ã‚ã¯æ°—ç´›ã‚Œ ã‚ªãƒ•ãƒ»ã‚³ãƒ¼ã‚¹
#
# >>>> CLUSTER:  9204
# >>>>  9204 ãƒã‚¸ãƒ£ãƒ³â€œãƒŠãƒ¼ãƒ©ãƒ¼ãƒ¤ãƒŠãƒ»ãƒãƒªâ€ (ã‚¤ãƒ³ãƒ‰ï¼ã‚·ãƒ£ã‚·ãƒ£ãƒ¼ãƒ³ã‚¯ã®ã‚¯ãƒ©ãƒ«) [unknown]
# >>>>  10228 ãƒã‚¸ãƒ£ãƒ³â€œãƒŠãƒ¼ãƒ©ãƒ¼ãƒ¤ãƒŠãƒ»ãƒãƒªâ€ [unknown]
# >>>>  13437 ãƒ›ãƒ¼ãƒŸãƒ¼ã®éŸ³ï¼ˆãƒ›ãƒ¼ãƒŸãƒ¼ï¼‰ - ãƒ¢ãƒ³ã‚´ãƒ«ã®ãƒ›ãƒ¼ãƒŸãƒ¼ï½žã‚¬ãƒ³ãƒœãƒ«ãƒ‰ã€ãƒ¤ãƒ´ã‚¬ãƒ¼ãƒ³ [unknown]
# >>>>  15440 ãƒ›ãƒ¼ãƒŸãƒ¼ã®éŸ³ï¼ˆãƒ›ãƒ¼ãƒŸãƒ¼ï¼‰ (ãƒ¢ãƒ³ã‚´ãƒ«ã®ãƒ›ãƒ¼ãƒŸãƒ¼ï½žã‚¬ãƒ³ãƒœãƒ«ãƒ‰ã€ãƒ¤ãƒ´ã‚¬ãƒ¼ãƒ³) [unknown]
#
# >>>> CLUSTER:  9210
# >>>>  9210 åŠ‰å¾·è¯ - ç¨è‡ªåŽ»å·æ­¡
#
# >>>> CLUSTER:  9263
# >>>>  9263 å¹¸ç¦çž¬é–“ - è–°è¡£è‰è‰ ç‰‡å°¾æ›² è¨±ç´¹æ´‹
# >>>>  18635 å¹¸ç¦çž¬é–“ - è–°è¡£è‰ ç‰‡å°¾æ›² (é‡è¦‹100%å¹¸ç¦ å¶åƒåŠ‡æƒ…æ­Œæœ€ç²¾é¸ è¨±ç´¹æ´‹
#
# >>>> CLUSTER:  9999
# >>>>  9999 å‚æœ¬çœŸç¶¾ - ã“ã¨ã¿ã¡
#
# >>>> CLUSTER:  10425
# >>>>  10425 0A1-E.E.G. The Rejects
#
# >>>> CLUSTER:  11471
# >>>>  11471 ã²ã¨ã‚Šã½ã£ã¡ã§è¸Šã‚‰ã›ã¦ (ç ”ãƒŠã‚ªã‚³ ãƒ™ã‚¹ãƒˆ) ç ”ãƒŠã‚ªã‚³
#
# >>>> CLUSTER:  12808
# >>>>  12808 ä¾µçŠ¯ ä½æ©‹ä¿Šå½¦
#
# >>>> CLUSTER:  13368
# >>>>  13368 æ—§ãæƒ³ã„ (ã²ãã‚‰ã—ã®ãªãé ƒã«ç¥­ ã‚ªãƒªã‚¸ãƒŠãƒ«ã‚µã‚¦ãƒ³ãƒ‰ãƒˆãƒ©ãƒƒã‚¯) ç§¦ä¿®
#
# >>>> CLUSTER:  13646
# >>>>  13646 äº•ä¸Šé™½æ°´ - ç¥žç„¡æœˆã«ã‹ã“ã‚Œã¾ã¦
#
# >>>> CLUSTER:  13660
# >>>>  13660 Ã—ï½žãƒ€ãƒ¡ï½ž (ã‚¿ã‚­ãƒ„ãƒãƒ™ã‚¹ãƒˆ) ã‚¿ãƒƒã‚­ãƒ¼ï¼†ç¿¼
# >>>>  15749 ã‚¿ãƒƒã‚­ãƒ¼ï¼†ç¿¼ - Ã—ï½žãƒ€ãƒ¡ï½ž
#
# >>>> CLUSTER:  13881
# >>>>  13881 æ·±æµ·ã®ç²¾ - ã‚ã¾ãˆãªã„ã§ã‚ˆã£!! ã•ã‚“ã¨ã‚‰å†¬ç›¤ å²©å´Žæ–‡ç´€
#
# >>>> CLUSTER:  13945
# >>>>  13945 å¥‡å­ (ç™¾é¬¼ç¹šä¹±) é™°é™½åº§
#
# >>>> CLUSTER:  14355
# >>>>  14355 å°ç™½ èˆ¹- ç‹¬å®¶çˆ±å”±4 çŽ‹çº
#
# >>>> CLUSTER:  14436
# >>>>  14436 ä¸‰åçŸ³ - åœ“ç”Ÿç‰¹é¸ãƒ©ã‚¤ãƒ´ 3 æ·€äº”éƒŽ/ä¸‰åçŸ³ ä¸‰éŠäº­åœ“ç”Ÿ
#
# >>>> CLUSTER:  14641
# >>>>  14641 å†¬ã®å¦–ç²¾ (é¢¨ç«‹ã¡ã¬) æ¾ç”°è–å­
# >>>>  17432 å†¬ã®å¦–ç²¾ æ¾ç”°è–å­
#
# >>>> CLUSTER:  14681
# >>>>  14681 ä¸€ä¹‹ç€¬å‰› & å¢—ç”°é †ä¸€ - ãƒ¯ã‚«ãƒã‚¿ã‚¦ãƒ³
#
# >>>> CLUSTER:  15011
# >>>>  15011 ä¸»é¡Œæ›² (æ…¢ç‰ˆ) Beyond
#
# >>>> CLUSTER:  15223
# >>>>  15223 æ„›ã‚’æ­¢ã‚ãªã„ã§ - YES-YES-YES ã‚ªãƒ•ã‚³ãƒ¼ã‚¹
#
# >>>> CLUSTER:  15608
# >>>>  15608 ãƒŸãƒ‹ãƒ‰ãƒ©ãƒžã€Œã©ã‚Œã¿ã®ãªã£ãŒãƒ¼ã„ä¸€æ—¥ã€ æ˜¥é¢¨ã©ã‚Œã¿ï¼ˆåƒè‘‰åƒæµå·³ï¼‰
#
# >>>> CLUSTER:  16099
# >>>>  16099 ãŸããŒã‚Œ (å°ã•ãªèŠ±ã€œã‚¢ãƒžãƒãƒ¼ãƒ©) Naoko Terai
#
# >>>> CLUSTER:  16410
# >>>>  16410 ã‚·ãƒ³ãƒ‡ãƒ¬ãƒ©ã¯é­”æ³•ä½¿ã„ - ãƒ ã‚½ã‚¦ãƒžãƒ†ãƒªã‚¢ãƒ©ã‚¤ã‚º xå‚ä¸Šãªã¡
#
# >>>> CLUSTER:  16478
# >>>>  16478 å¥³å­åäºŒä¹åŠ - ç–å‹’æ²³
#
# >>>> CLUSTER:  17032
# >>>>  17032 å¥¥è¯å­ - é€æ˜Žå‚˜
#
# >>>> CLUSTER:  17174
# >>>>  17174 ä¸‰è—©å¸‚çš„å’–å•¡å±‹ (å¬‰å“ˆå®¢) åŠ‰åŠ­å¸Œ
#
# >>>> CLUSTER:  17854
# >>>>  17854 ã‚³ãƒŠãƒŸçŸ©å½¢æ³¢å€¶æ¥½éƒ¨ - è¡€å¡—ã‚‰ã‚Œã—é—‡ã¸ã®ãƒˆãƒƒã‚«ãƒ¼ã‚¿
#
# >>>> CLUSTER:  17977
# >>>>  17977 ä¸åŸ’ãªåæ¯ã¨ç”˜ã„å˜˜ D'espairsRay
#
# >>>> CLUSTER:  17979
# >>>>  17979 å°¾å´Žç´€ä¸–å½¦ - ã•ã‚ˆãªã‚‰ã‚’ã‚‚ã†ä¸€åº¦
#
# >>>> CLUSTER:  18035
# >>>>  18035 ã„ãˆã‚ï½žãœã¶ã‚‰ - é›¨å¸°ã‚Š
#
# >>>> CLUSTER:  19307
# >>>>  19307 æœˆä¸‹ç¾Žäººå½¢ - å››æ¬¡å…ƒå‹å¥½æ¡ç´„ ãƒ´ã‚£ãƒ‰ãƒ¼ãƒ«
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  28
# >>>> CLUSTER:  8530
# >>>>  8530 å¹¡è°·å°šå² - FUU... (GAME OER)
#
# >>>> CLUSTER:  11981
# >>>>  11981 Ashes of Sodom - From the Ashes Sin of Anngels
#
# >>>> CLUSTER:  17449
# >>>>  17449 äº¤éŸ¿æ›²ç¬¬1ç•ªãƒçŸ­èª¿ä½œå“3(B.9)ã€Œã‚ºãƒ­ãƒ‹ãƒ„ã‚§ã®é˜ã€ ç¬¬2æ¥½ç« :ã‚¢ãƒ€ãƒ¼ã‚¸ãƒ§ãƒ»ãƒ‡ã‚£ãƒ»ãƒ¢ãƒ«ãƒˆ - éŠ€æ²³è‹±é›„ä¼èª¬ CD-BOX è‡ªç”±æƒ‘æ˜ŸåŒç›ŸSIDE Staatskapelle Berlin
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  29
# >>>> CLUSTER:  5642
# >>>>  5642 Accept Me The Harvey Averne Dozen
#
# >>>> CLUSTER:  7670
# >>>>  7670 AÃ±os 80 (feat. Amaral) - Fin (de la 2Âª parte) Los Piratas
# >>>>  10388 AÃ±os 80 (feat. Amaral) (Fin (de la 2Âª Parte)) Los P iratas
# >>>>  16618 AÃ±os 80 (feat. Amaral)) Los Piratas
#
# >>>> CLUSTER:  11076
# >>>>  11076 Age of Darkness - Lost Child Original Sound Track from S.S.H The Final Side-Z åŸ¼çŽ‰æœ€çµ‚å…µå™¨
#
# >>>> CLUSTER:  16249
# >>>>  16249 0A4-House of the Rising Sun Joan Baez
#
# >>>> CLUSTER:  17376
# >>>>  17376 Accept - Ahead of the Pack
#
# >>>> CLUSTER:  18857
# >>>>  18857 ä¼Šè—¤è³¢æ²» - Battle #44
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  30
# >>>> CLUSTER:  1287
# >>>>  1287 013-A Couple of Song and Dance Men Fred Astaire
# >>>>  2603 A Couple of Song and Daance Men Fred Astaire
# >>>>  15058 A COUPLE OF SONG AND DANCE MEN (GOLDEN GREATS) Fred Astaire
#
# >>>> CLUSTER:  2254
# >>>>  2254 Asphalt (Jug of Joy!) Molly Maguire
#
# >>>> CLUSTER:  2504
# >>>>  2504 ã•ã‚ˆãªã‚‰ã‚’ã‚‚ã†ä¸€åº¦ - ç¶šãƒ»é’æ˜¥æ­Œå¹´é‘‘ â€™71 PLUS å°¾å´Žç´€ä¸–å½¦
# >>>>  16752 ã•ã‚ˆãªã‚‰ã‚’ã‚‚ã†ä¸€åº¦ (ç¶šãƒ»é’æ˜¥æ­Œå¹´é‘‘ â€™71 PLUS) å°¾å´Žç´€ä¸–å½¦
#
# >>>> CLUSTER:  5045
# >>>>  5045 AC Black - Emotional Feelings
#
# >>>> CLUSTER:  6548
# >>>>  6548 æœ¬æ°—ã«ã—ãªã„ã§ - ãƒ€ãƒ¼ãƒ†ã‚£ãƒšã‚¢FLASHãƒ´ã‚©ãƒ¼ã‚«ãƒ«ãƒ™ã‚¹ãƒˆã‚³ãƒ¬ã‚¯ã‚·ãƒ§ãƒ³ã€Œãƒ©ãƒ–ãƒªãƒ¼ãƒ»ã‚¨ãƒ³ã‚¼ãƒ« ã‚ªãƒ³ãƒ»ã‚¹ãƒ†ãƒ¼ã‚¸ã€ åœ‹åºœç”°ãƒžãƒªå­
# >>>>  11887 æœ¬æ°—ã«ã—ãªã„ã§ (ãƒ€ãƒ¼ãƒ†ã‚£ãƒšã‚¢FLASHãƒ´ã‚©ãƒ¼ã‚«ãƒ«ãƒ™ã‚¹ãƒˆã‚³ãƒ¬ã‚¯ã‚·ãƒ§ãƒ³ã€Œãƒ©ãƒ–ãƒªãƒ¼ãƒ»ã‚¨ãƒ³ã‚¼ãƒ« ã‚ªãƒ³ãƒ»ã‚¹ãƒ†ãƒ¼ã‚¸ã€) åœ‹åºœç”°ãƒžãƒªå­
#
# >>>> CLUSTER:  8471
# >>>>  8471 Aspie Lispen - In The Wilderness
#
# >>>> CLUSTER:  15303
# >>>>  15303 0A4-I Keep Looking for a Better Way David Oliver
#
# >>>> CLUSTER:  16819
# >>>>  16819 Aage Kvalbein & Iver Kleive - Jag har hÃ¶rt om en stad ovan mÃ¥lnen
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  31
# >>>> CLUSTER:  1462
# >>>>  1462 å²©åž‚å¾³è¡Œ - Phantom ~ UNKNOWN
#
# >>>> CLUSTER:  1735
# >>>>  1735 As If We NeverSaid Goodbye - Sunset Boulevard (1995 Toronto cast) Andrew Lloyd Webber
# >>>>  7118 015-As If We Never Said Goodbye Andrew Lloyd Webber
#
# >>>> CLUSTER:  2980
# >>>>  2980 A Spoonful Blues Charley Patton
#
# >>>> CLUSTER:  11434
# >>>>  11434 A Coffin WarkoholiK
#
# >>>> CLUSTER:  18990
# >>>>  18990 Ã˜ - S-Bahn
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  32
# >>>> CLUSTER:  2305
# >>>>  2305 As I Ever Been - Month of Madness Freeway feat. Hezekiah
# >>>>  3021 As I Ever Been Freeway feat. Hezekiah
# >>>>  9614 025-As I Ever Been Freeway feat. Hezekiah
# >>>>  16719 As I Ever Been (Month of Madness) Freeway feat. Hezekiah
#
# >>>> CLUSTER:  2361
# >>>>  2361 Aquefrigide - Anima
#
# >>>> CLUSTER:  8628
# >>>>  8628 Ajax, Ajax (Ajax Forever!) Koos Alberts
#
# >>>> CLUSTER:  9463
# >>>>  9463 AG & Party Arty - War
#
# >>>> CLUSTER:  12140
# >>>>  12140 ä¸­å·ç¿”å­ - pretty please chocolate on top
#
# >>>> CLUSTER:  12548
# >>>>  12548 Ashford & Simpson with Teddy Pendergrass - Reach Out and Touch
#
# >>>> CLUSTER:  16177
# >>>>  16177 ãŠãªã‹ã«ã†ãšã¾ã(ã‚«ã‚¨ãƒ«ã®æ­Œ) - Breath of Fire Original Soundtrack Special Box é’æœ¨ä½³ä¹ƒ
#
# >>>> CLUSTER:  16437
# >>>>  16437 å®‡å¤šç”°ãƒ’ã‚«ãƒ« - Parody
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  33
# >>>> CLUSTER:  119
# >>>>  119 æ…ˆæ„›ã®è¨€è‘‰é›†/æ—¥å¸¸ä¼šè©±ç¯‡ - ã€Œãƒãƒ¤ãƒ†ã®ã”ã¨ã!ã€ ã‚­ãƒ£ãƒ©ã‚¯ã‚¿ãƒ¼CD 2 ãƒžãƒªã‚¢ starring ç”°ä¸­ç†æµ
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  34
# >>>> CLUSTER:  1020
# >>>>  1020 2007-05-17: A State of Trance #300, "Part 3: Menno de Jong": Pettelaarse Schans, Hertogenbosch, The Netherlands Armin van Buuren
# >>>>  3940 2007-05-17: A State of Trance #300, "Part 3: Menno de Jong": Pettelaarse Schans, Hertogenbosch, The Netherlands (2007-05-17: A State of Trance #300: Pettelaarse Schans, Hertogenbosch, The Netherlands) Armin van Bunuren
# >>>>  12096 2007-05-17: A State of Trance #300, "Part 3: Menno de Jong": Pettelaarse Schans, Hertogenbosch, The Netherlands Armin van Buuren
#
# >>>> CLUSTER:  4476
# >>>>  4476 Ash - Different Today
#
# >>>> CLUSTER:  9457
# >>>>  9457 ãŸã‚ˆã‚Šã‚Šã«ãªã‚‹å…ˆè¼©? (TVãƒ‹ãƒ¡ ã€Žã²ã ã¾ã‚Šã‚¹ã‚±ãƒƒãƒÃ—â˜†â˜†â˜†ã€ ã‚ªãƒªã‚¸ãƒŠãƒ«ã‚µã‚¦ãƒ³ãƒ‰ãƒˆãƒ©ãƒƒã‚¯ ã€Žã²ã ã¾ã‚Šãƒ»ã§ã„ãšãƒ»ãªã„ã¨ã€) èŠè°·çŸ¥æ¨¹
#
# >>>> CLUSTER:  12249
# >>>>  12249 017-Acid Funk Modern Bazaar
# >>>>  12818 Acid Funk Modern Bazaar
#
# >>>> CLUSTER:  14084
# >>>>  14084 August Friedrich Martin Klughardt - Concertin ofÃ¼r Oboe und Orchester, Op. 18: I. Ziemlich lebhaft
#
# >>>> CLUSTER:  16550
# >>>>  16550 ãƒŸã‚¹ãƒ»ã‚¢ãƒ³ãƒŠ (the BOOGIE JACK) BOOGIE JACK
#
# >>>> CLUSTER:  17097
# >>>>  17097 Act of God - Life Denied
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  35
# >>>> CLUSTER:  315
# >>>>  315 013-Act 2, Scene III: Recitativo - Voi quel folgio lasciate (Serse/Atalanta) Georg Friedrich Handel
# >>>>  3614 Act 2, Scene III: Recitativo - Voi quel folgio lasciate (Serse/Atalanta) Georg Friedrich HÃ¤ndel
#
# >>>> CLUSTER:  1276
# >>>>  1276 Acid-Hustle-(Finger-Lickin'-Thang-4) Plump-DJs
#
# >>>> CLUSTER:  2466
# >>>>  2466 Act 3: Scene 2: The Commune de Paris - The Collection Roger Waters
#
# >>>> CLUSTER:  2613
# >>>>  2613 AC/DC - Rock'n Roll Damnation (Apollo Theatre Glasgow April 1978)
#
# >>>> CLUSTER:  2620
# >>>>  2620 Aesthetics of Yice - Dismissed Charlie Brown Gets a Valentine
# >>>>  5084 003-Aesthetics of Vice Charlie Brown Gets a Vallentine
#
# >>>> CLUSTER:  2762
# >>>>  2762 Acid Jack (Fabric 21: DJ Heather (Radio Mix)) Max Renn
# >>>>  2976 Acid Jack Max Renn
#
# >>>> CLUSTER:  3960
# >>>>  3960 021-Aquatica (full mix) Eliot Pulse
# >>>>  13407 Aquatica (full mix) - Elemental Pulse
#
# >>>> CLUSTER:  4498
# >>>>  4498 008-Act 1 - Tutto e chiaro... Tosca? Che non mi veda... Mario ! Mario ! Giacomo Puccini
# >>>>  8163 Act 1 - Tutto Ã¨ chiaro... Tosca? Che non mi veda... Mario ! Mario ! Giacomo Puccini
# >>>>  13421 Act 1 - Tutto Ã¨ chiaro... Tosca? Che non mi veda... Mario ! Mario ! - Tosca (disc 1) Giacomo Puccini
#
# >>>> CLUSTER:  4647
# >>>>  4647 Act III: Comfort Me Shadow Gallery
# >>>>  5034 Act III: Comfort Me (Room V) Shadow Gaallery
#
# >>>> CLUSTER:  5632
# >>>>  5632 Acts 27 (ESV The New Testament on CD) Marquis Laughlin
#
# >>>> CLUSTER:  5710
# >>>>  5710 Act II - A squandered love, an empty life (The Tyrant's Parable) Tettix
#
# >>>> CLUSTER:  5817
# >>>>  5817 011-Aesthetics Aphilas
# >>>>  6865 Aesthetics - Prisoners of the Planet Aphilas
#
# >>>> CLUSTER:  9752
# >>>>  9752 Ã‘ak DjeriÃ±o - LÃ´ BÃ¢ MeÃ¯ TeÃ¯ ShÃ´
#
# >>>> CLUSTER:  10082
# >>>>  10082 Acoustic Sound Orchestra - Smoke Gets in Your Eyes
#
# >>>> CLUSTER:  10184
# >>>>  10184 Act 1: Someone Else's Story BjÃ¶rn Ulvaeus & Benny Andersson
#
# >>>> CLUSTER:  10580
# >>>>  10580 Ajat sitten luopuneet aRtsia
# >>>>  13559 Ajat sitten luopuneet - Antologia Ratsia
# >>>>  16841 Ajat sitten luopuneet (Antologia) Ratsia
#
# >>>> CLUSTER:  17283
# >>>>  17283 010-Act Together The Rolling Stones
#
# >>>> CLUSTER:  18824
# >>>>  18824 008-As Catch Can Gerry Mulligan
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  36
# >>>> CLUSTER:  9024
# >>>>  9024 Acid Yellow (Sonny) Clint Mansell
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  37
# >>>> CLUSTER:  3
# >>>>  3 Action PAINTING! - Mustard Gas
#
# >>>> CLUSTER:  33
# >>>>  33 016-Action (interlude) Hell
# >>>>  2670 Action (interlude) - eTufelswerk Hell
# >>>>  17211 Action (interlude) Hell
#
# >>>> CLUSTER:  116
# >>>>  116 Acting (2005-04-02: The Spanish Moon, Baton Rouge, LA, USA) Macrosick
# >>>>  3605 Acting Macrosick
# >>>>  5723 Acting - 2005-04-02: The Spanish Moon, Baton Rouge, LA, USA Macrosick
# >>>>  7240 009-Acting Macrosick
#
# >>>> CLUSTER:  946
# >>>>  946 As Time Goes By (Casablanca) - Conniff no Cinema & Tempos Modernos Ray Conniff
#
# >>>> CLUSTER:  1305
# >>>>  1305 Actionize 3 Art Phillips
#
# >>>> CLUSTER:  1416
# >>>>  1416 Acadian Driftwood (Northern Lights - Southern Cross) Band
#
# >>>> CLUSTER:  2125
# >>>>  2125 Action In The Dusk - ê°œì™€ ëŠ‘ëŒ€ì˜ ì‹œê°„ [unknwn]
# >>>>  10259 Action In The Dusk [unknown]
# >>>>  14773 Action In The Dusk (ê°œì™€ ëŠ‘ëŒ€ì˜ ì‹œê°„) [unknown]
# >>>>  17936 014-Action In The Dusk [unknown]
#
# >>>> CLUSTER:  3884
# >>>>  3884 accidnets Don't Happen - Fandam Plus Elâ€P
# >>>>  5679 accidnets Dotn't Happen (Fandam Plus) Elâ€P
# >>>>  7727 009-accidnets Don't Happen ElP
# >>>>  15215 accidnets Don't Happen Elâ€P
#
# >>>> CLUSTER:  5041
# >>>>  5041 Aqua Dementia (Live at Brixton) Mastodon
#
# >>>> CLUSTER:  6757
# >>>>  6757 15 AÃ±os Tiene Mi Amor (La DÃ©cada Prodigiosa) La DÃ©cada Prodigiosa
#
# >>>> CLUSTER:  6781
# >>>>  6781 Act III: When I have often heard - The Fairy Queen (Deller Consort, Alfred Deller) Henry Purcell
# >>>>  7004 Act III: When I have often heard (The Fairy Queen (Deller Consort, Alfred Deller)) Henry Purcell
#
# >>>> CLUSTER:  7890
# >>>>  7890 As Time Goes By (Pirkko, Brita ja Vieno) Brita Koivunen
#
# >>>> CLUSTER:  9072
# >>>>  9072 007-Accident LFATBACKER
# >>>>  17973 Accident FLATBACKER
#
# >>>> CLUSTER:  9496
# >>>>  9496 ã‚ˆã„ã“ã®ãƒãƒ¤ãƒ†ã‹ã‚‹ãŸã€Œã¤ã€ - ã€Œãƒãƒ¤ãƒ†ã®ã”ã¨ã!!ã€ ã‚­ãƒ£ãƒ©ã‚¯ã‚¿ãƒ¼CD 2nd series 04 ç¶¾å´Žãƒãƒ¤ãƒ† starring ç™½çŸ³æ¶¼å­
# >>>>  12598 ã‚ˆã„ã“ã®ãƒãƒ¤ãƒ†ã‹ã‚‹ãŸã€Œã¤ã€ (ã€Œãƒãƒ¤ãƒ†ã®ã”ã¨ã!!ã€ ã‚­ãƒ£ãƒ©ã‚¯ã‚¿ãƒ¼CD 2nd series 04) ç¶¾å´Žãƒãƒ¤ãƒ† starring ç™½çŸ³æ¶¼å­
#
# >>>> CLUSTER:  10031
# >>>>  10031 Acting Suspicious - Urba Drama Ashford
#
# >>>> CLUSTER:  11610
# >>>>  11610 åœ°çƒã¯äººç‰©é™³åˆ—å®¤ - UTENA La Fillette RÃ©volutionnaire Complete CD-BOX å…‰å®—ä¿¡å‰
#
# >>>> CLUSTER:  13371
# >>>>  13371 015-Action / Chase: Future City Donn
#
# >>>> CLUSTER:  14774
# >>>>  14774 å–œå¤šæ¢æ•¦å¿— - Steamy Travelling Mood Epic Battle
#
# >>>> CLUSTER:  16728
# >>>>  16728 Ä°stanbul - Ä°stanbul / Why Cem Karaca & ApaÅŸlar
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  38
# >>>> CLUSTER:  199
# >>>>  199 Astronomy Domine - The Piper at the Gates of Dawn Pink Floyd
# >>>>  5119 Astronomy Domine (The Piper at the Gates of Dawn) Pink Floyd
# >>>>  6417 Astronomy Domine Pink Floyd
# >>>>  13210 001-Astronomy Domine Pink Floyd
#
# >>>> CLUSTER:  762
# >>>>  762 ÄŒist' drug svet (Lajf navadnega Äloveka) Flirrt
# >>>>  4976 ÄŒist' drug svet - Lkajf navadnega Äloveka Flirrt
#
# >>>> CLUSTER:  987
# >>>>  987 Asterius - A Greater Path
#
# >>>> CLUSTER:  3119
# >>>>  3119 As Ek Droom Albert sde Wet
# >>>>  9653 As Ek Droom (Dagboek van 'n Dromer) Albert de Wet
# >>>>  11998 As Ek Droom - Dagboek van 'n Dromer Alberct de Wet
#
# >>>> CLUSTER:  3766
# >>>>  3766 Astrud Gilberto - Berimbou
#
# >>>> CLUSTER:  4706
# >>>>  4706 Asturias (The Ultimate Guitar Collection) Isaac AlbÃ©niz
# >>>>  8318 Asturias Isaac AlbÃ©niz
# >>>>  12036 001-Asturias Isaac Albeniz
# >>>>  17533 Asturias - The Ultimate Guitar Collection Isaac AlbÃ©niz
#
# >>>> CLUSTER:  5252
# >>>>  5252 Astor Piazzolla - Tapera
#
# >>>> CLUSTER:  5561
# >>>>  5561 0A3-Strag di ostacoli Cripple Bastards
#
# >>>> CLUSTER:  6721
# >>>>  6721 0A3-Straight From the Heart Peabo Bryson
#
# >>>> CLUSTER:  8098
# >>>>  8098 Austra Pumpure - PilsÄ“tÄ, kurÄ piedzimst vÄ“jÅ¡ unknown
#
# >>>> CLUSTER:  8568
# >>>>  8568 Astor Piazzolla - Pigmalion
#
# >>>> CLUSTER:  9529
# >>>>  9529 Asa Di War - Part 1 Bhai Ravinder Singh Ji
# >>>>  15928 Asa Di War - Part 1 Bhai Ravinder Singh Ji
# >>>>  16989 Asa Di War - Part 1 Bhai Ravinder Singh Ji
# >>>>  17900 Asa Di War - Part 1 Bhai Ravinder Singh Ji
#
# >>>> CLUSTER:  10296
# >>>>  10296 Astronaut Farewell Blues Decoder Ring
# >>>>  10557 009-Astronaut Farewell Blues Decoder Ring
# >>>>  17598 Astronaut Farewell Blues (They Blind the Stars, and the Wild Team) Decoder Ring
#
# >>>> CLUSTER:  14092
# >>>>  14092 As the Rain - 107.1 KGSR Broadcasts, Volume 6 Jeb Loy Nichols
#
# >>>> CLUSTER:  15940
# >>>>  15940 ä¸Šç”°é›…ç¾Ž - Tyrant Breaking Loose
#
# >>>> CLUSTER:  16206
# >>>>  16206 010-Acto I: Reste la, maintenant, pendant que je lirai Georges Bizet
#
# >>>> CLUSTER:  17223
# >>>>  17223 A Strange Boy - Hejira Joni Mitchell
#
# >>>> CLUSTER:  17294
# >>>>  17294 ãƒ¢ãƒ¼ãƒ‹ãƒ³ã‚°å¨˜ã€‚ - Souda! We're ALIVE
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  39
# >>>> CLUSTER:  6502
# >>>>  6502 Azul Natalia Clavier
# >>>>  9929 003-Azul Natalia Clavier
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  40
# >>>> CLUSTER:  5385
# >>>>  5385 æˆ€ä¸€ä¸–çš„æ„› (Loving a Life-Long Love) - å–œåŠ‡ä¹‹çŽ‹é›»å½±åŽŸè²å¸¶(Original Soundtrack of King of Comedy) èŽ«æ–‡è”š
#
# >>>> CLUSTER:  7225
# >>>>  7225 A Self-Made Man David Byrne
# >>>>  10179 A Self-Made Man - David Byrne David Byrne
# >>>>  16826 A Self-aMde  Man (David Byrne) David Byrne
# >>>>  18069 004-A Self-Made Man David Byrne
#
# >>>> CLUSTER:  14086
# >>>>  14086 Azul Violeta - El Amar y el Querer
#
# >>>> CLUSTER:  15791
# >>>>  15791 0A1-Clipped Curve
#
# >>>> CLUSTER:  17164
# >>>>  17164 A Schoolboy's Charm (The Golden Band) American Analog Set
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  41
# >>>> CLUSTER:  9785
# ...
# >>>>  2217 You & I (radio version) - The Cream of Female Vocal-Trance, Volume 2 Cinzia
# >>>>  4073 You & I (radio version) (The Cream of Female Vocal-Trance, Volume 2) Cinzia
# >>>>  11026 018-You & I (radio version) Cinzia
#
# >>>> CLUSTER:  1876
# >>>>  1876 YardbirdSuite(SimplyJazzGreats) HerbieMann
#
# >>>> CLUSTER:  11714
# >>>>  11714 You Ready for Me - Man With the Fun Maxi Priest
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3086
# >>>> CLUSTER:  9248
# >>>>  9248 YrittÃ¤jÃ¤in Fenniassa (Legendan laulut: Kaikki levytykset 1963â€“1990) Juha Vainio
#
# >>>> CLUSTER:  14492
# >>>>  14492 yRidge (Raft) Pumice
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3087
# >>>> CLUSTER:  16322
# >>>>  16322 Yurdal Tokcan - Bende Can
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3088
# >>>> CLUSTER:  172
# >>>>  172 011-You're the Only Good Thing (That's Happened to Me) Jim Reeves
# >>>>  1311 You're the Only Good Thing (That's Happened to Me) Jim Reeves
#
# >>>> CLUSTER:  16792
# >>>>  16792 Your Time Is Mine The Autumn Offering
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3089
# >>>> CLUSTER:  7653
# >>>>  7653 You're the Heart of Me Kathy Troccoli
# >>>>  9954 004-You're the Heart of Me Kathy Troccoli
# >>>>  10056 You're the Heart of Me (Greatest Hits) Kathy Troccoli
# >>>>  11112 You're the Heart of Me - Greatest Hits Katyh Troccoli
#
# >>>> CLUSTER:  16342
# >>>>  16342 Your True Love - For You Baby Continentals
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3090
# >>>> CLUSTER:  824
# >>>>  824 Your Love (The One You Need) Shane & Shane
#
# >>>> CLUSTER:  1541
# >>>>  1541 013-You're Lovely, Madame Benny Goodman
# >>>>  13249 You're Lovely, Madame Benny Goodman
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3091
# >>>> CLUSTER:  9606
# >>>>  9606 Your Light (Awakening the Oceans) Dst of Basement
#
# >>>> CLUSTER:  17920
# >>>>  17920 You Really Got Me (live) (Rarities: Attack of The Smithereens) Smithereens feat. The Kinks
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3092
# >>>> CLUSTER:  11483
# >>>>  11483 You're Old Enough to Fall in Love (Danny Bonaduce) Danny Bonaduce
# >>>>  13617 You're Old Enough to Fall in Love - Danny Bonaduce Danny Bonaduce
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3093
# >>>> CLUSTER:  1833
# >>>>  1833 010-You're Nobody 'Til Somebody Loves You Wheelhouse
# >>>>  7194 You're Nobody 'Til Somebody Loves You Wheelhouse
#
# >>>> CLUSTER:  5556
# >>>>  5556 Your Own Fault (Gory Gory Halleluja!) S.M.E.S.
#
# >>>> CLUSTER:  14264
# >>>>  14264 002-You're an Apple, I'm an Orange Big Fat Snake
#
# >>>> CLUSTER:  14700
# >>>>  14700 Your Move (a) - Emotional Undercurrents Stuart Roslyn
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3094
# >>>> CLUSTER:  12321
# >>>>  12321 001-You're My Candy Sweet Fatback
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3095
# >>>> CLUSTER:  9455
# >>>>  9455 Your Mother Loves You Son - CMJ New Music Monthly, Volume 116: September 2003 Beulah
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3096
# >>>> CLUSTER:  5007
# >>>>  5007 016-Your Molecular Structure Mos Allison
# >>>>  11514 Your Molecular Structure - The Best of Mose Allison Mose Allison
#
# >>>> CLUSTER:  13158
# >>>>  13158 013-You Are My Life PMichael Jackson
# >>>>  18326 You Are My Life - King of Pop (The Korean Limited Edition) Michael Jackson
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3097
# >>>> CLUSTER:  11187
# >>>>  11187 YÃ©roum oh YÃ©roum - Marie-JosÃ© Casanova chante Boris Vian Marie-JosÃ© Casanova
#
# >>>> CLUSTER:  18847
# >>>>  18847 You're My Remedy (At Abbey Road) Helen Shapiro
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3098
# >>>> CLUSTER:  1110
# >>>>  1110 21z-
#
# >>>> CLUSTER:  5091
# >>>>  5091 ×“× ×™××œ ×¡×œ×•×ž×•×Ÿ - ×œ×‘ ×–×”×‘
# >>>>  11382 ×œ×‘ ×–×”×‘ - × ×™××œ ×¡×œ×•×ž×•×Ÿ ×“× ×™××œ ×¡×œ×•×ž×•×Ÿ
#
# >>>> CLUSTER:  15269
# >>>>  15269 æ˜Žæ—¥ã«å‘ã‹ã£ã¦ æœ‰æ¾¤å­ç´€
#
# >>>> CLUSTER:  15299
# >>>>  15299 × ×§×ž×ª ×”×˜×¨×§×˜×•×¨ - ×¢×œ ×”×§×¦×”
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3099
# >>>> CLUSTER:  9739
# >>>>  9739 Zbieg okolicznoÅ›ci Å‚agodzÄ…cych (Bieszczadzkie anioÅ‚y) Stare Dobre MaÅ‚Å¼eÅ„stwo
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3100
# >>>> CLUSTER:  4870
# >>>>  4870 Zeep - Know More Now
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3101
# >>>> CLUSTER:  12686
# >>>>  12686 Zbatata feat. Soprano - Amigo
#
# >>>> CLUSTER:  17890
# >>>>  17890 ZoÃ« Badwi - Freefallin' (Hardforze remix)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3102
# >>>> CLUSTER:  3187
# >>>>  3187 009-Zo ver weg Guus Meeuwis & Vagant
# >>>>  18607 Zo ver weg - Verbazing Guus Meeuwis & Vagant
#
# >>>> CLUSTER:  8596
# >>>>  8596 Zebra Stripes (narration) - Animal Tails Charles Woods & E. Macdonald
# >>>>  14521 025-Zebra Stripes (narration) Charles Woods & E. Macdonald
#
# >>>> CLUSTER:  12018
# >>>>  12018 Zabriskie Point: Crumbling Land Pink Floyd
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3103
# >>>> CLUSTER:  763
# >>>>  763 æŽå¿ƒæ½” - ç­”æ‡‰
#
# >>>> CLUSTER:  17370
# >>>>  17370 ×ž×ª×™ ×›×¡×¤×™ ×•×©×œ×ž×” ×’×¨×•× ×™×š - ×‘×Ÿ ×’×•×¨×™×•×Ÿ
#
# >>>> CLUSTER:  17473
# >>>>  17473 æž—æ†¶è“® - ä¸–ç•Œå¿«æ¨‚
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3104
# >>>> CLUSTER:  12703
# >>>>  12703 Zaz - Je veux (unplugged)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3105
# >>>> CLUSTER:  3218
# >>>>  3218 Za svÃ­tÃ¡nÃ­ - Jsem hlÃ­na, jsem strom, jsem stroj VladimÃ­r VÃ¡clavek
#
# >>>> CLUSTER:  14918
# >>>>  14918 (Zazie fait de la) bicyclette plastiscines
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3106
# >>>> CLUSTER:  16706
# >>>>  16706 Zwickt's mi (Ã–3 Greatest Hits, Volume 14) Wolfgang Ambros
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3107
# >>>> CLUSTER:  3024
# >>>>  3024 Zo gaat het leven aan je voor (Hillich fjoer | Heilig vuur) Syb van der Ploeg
# >>>>  3435 Zo gaat het leven aan je voor Syb van der Ploeg
# >>>>  12620 Zo gaat het leven aan je voor - Hillich fjoer | Heilig vuur Syb van der Ploeg
# >>>>  12854 006-Zo gaat het leven aan je voor Syb van der Ploeg
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3108
# >>>> CLUSTER:  17754
# >>>>  17754 003-Zouk & Love Caribbean Team
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3109
# >>>> CLUSTER:  16961
# >>>>  16961 ZezÃ© Gonzaga - InquietaÃ§Ã£o
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3110
# >>>> CLUSTER:  1297
# >>>>  1297 Zigmars LiepiÅ†Å¡ - NolÄdÄ“ts (DÄ«terihs un ziÅ†otÄji)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3111
# >>>> CLUSTER:  10763
# >>>>  10763 Zagoraa Doug Robinson
#
# >>>> CLUSTER:  16730
# >>>>  16730 ZSK - Where Are You?
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3112
# >>>> CLUSTER:  6477
# >>>>  6477 Zagora (JAZZIZ on Disc: October 2000) Doug Robinson
#
# >>>> CLUSTER:  11972
# >>>>  11972 Zac Crouse - The 1st Time (feat. Jessie Tesolin)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3113
# >>>> CLUSTER:  1806
# >>>>  1806 Zaho - Jardin d'Eden
#
# >>>> CLUSTER:  12208
# >>>>  12208 Zigaretten Rauchen feat. Rosa - MÃ¤nner (radio mix)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3114
# >>>> CLUSTER:  9709
# >>>>  9709 004-Zegarmistrz swiata Kult
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3115
# >>>> CLUSTER:  14011
# >>>>  14011 Zeta Bieng (original version) - 6th Element Zymosis
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3116
# >>>> CLUSTER:  2059
# >>>>  2059 Zodiac 99 Dr. Olive
# >>>>  14433 004-Zodiac 99 Dr. Olive
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3117
# >>>> CLUSTER:  6975
# >>>>  6975 Zodiac 99 - First DJ on the Moon Dr. Olive
# >>>>  18628 Zodiac 99 (First DJ on the Moon) Dr. Olive
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3118
# >>>> CLUSTER:  19175
# >>>>  19175 Zwotackter - Miss Vegas
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3119
# >>>> CLUSTER:  863
# >>>>  863 015-Ze do Caroco Grupo Revelacao
#
# >>>> CLUSTER:  12670
# >>>>  12670 001-ZDisorder Joy Division
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3120
# >>>> CLUSTER:  6086
# >>>>  6086 ZdenÄ›k PololÃ¡nÃ­k & Karel VÃ¡gner - Fairs & Carousels: Shooting Gallery
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3121
# >>>> CLUSTER:  4127
# >>>>  4127 "Zu Hilfe! Zu Hilfe!" (Tamino, die drei Damen) (Die ZauberflÃ¶te) Wolfgagn Amadeus Mozart
# >>>>  12416 "Zu Hilfe! Zu Hilfe!" (Tamino, die drei Damen) - Die ZauberflÃ¶te Wolfgang Amadeus Mozart
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3122
# >>>> CLUSTER:  3275
# >>>>  3275 Za ljubav hvala ti - Anno Domini 1996. E.T.
# >>>>  11598 007-Za ljubav hvala ti E.T.
# >>>>  16992 Za ljubav hvala ti E.T.
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3123
# >>>> CLUSTER:  12478
# >>>>  12478 ZolloZkunstStoFF ZolloZ
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3124
# >>>> CLUSTER:  1524
# >>>>  1524 Zelda Pinwheel - Nothing Yet Circles Red Robots?
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3125
# >>>> CLUSTER:  2144
# >>>>  2144 ÐžÐ¹, ÐºÑ€Ð°ÑÐ¸Ð²Ñ‹Ðµ Ð³Ð»Ð°Ð·Ð° - Ð’ Ð´ÐµÑÑÑ‚Ð¾Ñ‡ÐºÑƒ 8 ÐÑÐ½ÑÐ¸
# >>>>  8238 ÐžÐ¹, ÐºÑ€Ð°ÑÐ¸Ð²Ñ‹Ðµ Ð³Ð»Ð°Ð·Ð° ÐÑÐ½ÑÐ¸
# >>>>  8297 ÐžÐ¹, ÐºÑ€Ð°ÑÐ¸Ð²Ñ‹Ðµ Ð³Ð»Ð°Ð·Ð° (Ð’ Ð´ÐµÑÑÑ‚Ð¾Ñ‡ÐºÑƒ 8) ÐÑÐ½ÑÐ¸
#
# >>>> CLUSTER:  3360
# >>>>  3360 ÐžÐ±ÐµÑ€Ð½Ð¸Ñ‚ÐµÑÑŒ Ð“Ñ€Ð¸Ð³Ð¾Ñ€Ð¸Ð¹ Ð›ÐµÐ¿Ñ
# >>>>  11601 ÐžÐ±ÐµÑ€Ð½Ð¸Ñ‚ÐµÑÑŒ - ÐŸÐµÐ½ÑÐ½Ðµ Ð“Ñ€Ð¸Ð³Ð¾Ñ€Ð¸Ð¹ Ð›ÐµÐ¿Ñ
# >>>>  14994 ÐžÐ±ÐµÑ€Ð½Ð¸Ñ‚ÐµÑÑŒ (ÐŸÐµÐ½ÑÐ½Ðµ) Ð“Ñ€Ð¸Ð³Ð¾Ñ€Ð¸Ð¹ Ð›ÐµÐ¿Ñ
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3126
# >>>> CLUSTER:  1059
# >>>>  1059 010-Zum Abendsegen "Herr, sei gnadig unserm Flehn" Felix Mendelssohn
# >>>>  17439 Zum Abendsegen "Herr, sei gnÃ¤dig unserm Flehn" - Motets Op. 23, 69 & 78 / Psaume 100 / Missa breve (RIAS-Kammerchor feat. conductor: Marcus Creed) Felix Mendelssohn
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3127
# >>>> CLUSTER:  3507
# >>>>  3507 ZiemsvÄ“tku Dziesma - Christmas in Latvia PÄ“teris AldiÅ†Å¡
# >>>>  7468 012-Ziemsvetku Dziesma Peteris Aldins
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3128
# >>>> CLUSTER:  2769
# >>>>  2769 Znouzectnost - PohÃ¡dka
#
# >>>> CLUSTER:  12417
# >>>>  12417 æ¾æžè³€å­ & æ±Ÿå£è²´å‹… - Misty Eyed (instrumental)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3129
# >>>> CLUSTER:  13052
# >>>>  13052 Zon zien zakken (Op Avontuur) Kaatje
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3130
# >>>> CLUSTER:  13473
# >>>>  13473 Zangeres Zonder Naam - De soldatenmoeder
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3131
# >>>> CLUSTER:  11632
# >>>>  11632 Ziondab La Golden Acapulco
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3132
# >>>> CLUSTER:  9301
# >>>>  9301 10 Zomers Lang De Romeo's
# >>>>  14733 011-10 Zomers Lang De Romeo's
# >>>>  14855 10 Zomers Lang (Feesten in Stijl)
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3133
# >>>> CLUSTER:  6771
# >>>>  6771 zmir'in KÄ±zlarÄ± Sezen Aksu
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3134
# >>>> CLUSTER:  19068
# >>>>  19068 003-Zero Hour Frostiva
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3135
# >>>> CLUSTER:  479
# >>>>  479 001-Zero Sex Christian Death
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3136
# >>>> CLUSTER:  5560
# >>>>  5560 7 Zwerge - Steh' auf, wenn du auf Zwerge stehst
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3137
# >>>> CLUSTER:  9331
# >>>>  9331 Zirkel (SNSM Records Anthology Box Set) twaelve
# >>>>  11838 Zirkel - SNSM Records Anthology Box Set Twelve
# >>>>  15079 Zirkel Twelve
#
# >>>> CLUSTER:  15723
# >>>>  15723 004-Zirkel Twelve
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3138
# >>>> CLUSTER:  19101
# >>>>  19101 Zorgongollac - Mostro Morkobot
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3139
# >>>> CLUSTER:  13127
# >>>>  13127 ZAR - Tre polkaer fra LÃ¦sÃ¸: Jens Lyngses polka / Jysk fynsk / Kingo Pedersens vestenom
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3140
# >>>> CLUSTER:  4336
# >>>>  4336 ZrymgÃ¶ll - Trolls Lurking Beer
#
# ----------------------------------------------------------------------------------------------------
# CLUSTERS DO BLOCK  3141
# >>>> CLUSTER:  13868
# >>>>  13868 Zahyara (Mirko Loko remix) - Zahyara EP Optional Feast
# >>>>  17825 Zahyara (Mirko Loko remix) (Zahyara EP) Optional Feast
# >>>>  18552 Zahyara (Mirko Loko remix) Optional Feast
#
# ----------------------------------------------------------------------------------------------------
